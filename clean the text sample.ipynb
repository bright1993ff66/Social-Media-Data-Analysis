# %% [markdown]
# # 1. Load relevant packages

# %%
# Commonly used
import numpy as np
import pandas as pd
import os
import string
from collections import Counter
import re
from datetime import datetime, timedelta
from codecs import encode
import pytz

# A package for preprocessing(officially used in SemEval NLP competition)
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

from sklearn.utils import shuffle

# %% [markdown]
# # 2. Load an uncleaned dataset and randomly sample 20 tweets for preprocessing

# %% [markdown]
# ### Load an uncleaned tweet dataset first

# %%
tweet_2017_path = r'F:\CityU\Datasets\Hong Kong Tweets 2017'
final_uncleaned = pd.read_pickle(os.path.join(tweet_2017_path, 'final_uncleaned.pkl'))

# %% [markdown]
# ### Construct Chinese tweets and English tweets dataframe

# %%
en_tweets = final_uncleaned.loc[final_uncleaned['lang'] == 'en']
zh_tweets = final_uncleaned.loc[final_uncleaned['lang'] == 'zh']

# %% [markdown]
# ### Randomly sample 15 tweets in each dataframe

# %%
en_tweets_sample = en_tweets.sample(15)
zh_tweets_sample = zh_tweets.sample(15)

# %%
zh_tweets_sample.shape
# Out:
# (15, 44)

# %%
en_tweets_sample.shape
# Out:
# (15, 44)

# %%
all_sample_tweets = pd.concat([en_tweets_sample, zh_tweets_sample])

# %%
final_sample_tweets = shuffle(all_sample_tweets)

# %%
final_sample_tweets = final_sample_tweets[['user_id_str', 'lang', 'text', 'url', 'lat', 'lon']]

# %% [markdown]
# ### Show how the dataframe looks like

# %%
final_sample_tweets
# Out:
#       user_id_str lang                                               text  \
# 1    5.759862e+06   zh  æäºäºæ
# ä¸æ¯æéå¯ä»¥æ²æ·¡â¯åå¹´ä...
# 314  1.227044e+08   en  Motto in HK day 2 #motto #gdragon #gdragonhkco...
# 2    4.053995e+09   en  06:48 Temp. 22.9Â°C, Hum. 73%, Dewp. 16.7Â°C, ...
# 62   1.540248e+07   zh  @miniyoshima @happynatalie @_lamdavid @uituit ...
# 5    3.146791e+09   en  @akari_oozora Source: "Three statues" by yewen...
# 170  8.296432e+06   zh  é·è¤¸åºåæå°èªå·±èº«æææä¿¡å¿ @ H...
# 51   1.406596e+07   zh  Sai Kung Town â¢ Sai Kung, Hong Kong â¢ è¥¿è...
# 99   2.189156e+08   en  I'm at Ho Hung Kee in Causeway Bay https://t.c...
# 98   6.798813e+07   zh  The price of dim sum in hkg í ½í±\n#onedimsum...
# 69   5.389315e+07   zh  <U+6CD5><U+5F0F><U+5343><U+5C64><U+9165><U+86C...
# 256  1.558236e+07   zh  #reuniondinner2017 #<U+5718><U+5E74><U+98EF>20...
# 121  1.986098e+07   en  It's on! #ArtBaselHK #AlanCristeaGallery 1B30 ...
# 136  5.417862e+06   zh  <U+6930><U+5B50><U+70AD> &amp; 70% <U+7DA0><U+...
# 84   2.712375e+08   zh  #gathering #okonomiyaki @ éé å å¾¡å¥½ç-é...
# 13   5.135450e+07   zh  Live Band çä¿åå¾é  #ê¹íì° #íì° #...
# 134  2.922512e+08   zh  Happy Easter!<U+5FA9><U+6D3B><U+7BC0><U+5FEB><...
# 265  2.455825e+07   zh  #<U+7121><U+795E><U+795E><U+56DB><U+570D><U+9A...
    without_u = remove_u_plus(text)
    old_text = without_u
    old_text = old_text.encode('unicode_escape').decode('utf-8')
    result1 = re.sub(pattern='\\\\r', repl='', string=old_text)
    result2 = re.sub(pattern='\\\\n', repl='', string=result1)
    result3 = re.sub(pattern='\\\\x([a-z0-9]{2})', repl = '<\\1>', string=result2)
    old_text = result3
    for _, row in emoji_dictionary.iterrows():
        if row['R_Encoding'] in old_text:
            new_text = re.sub(pattern=row['R_Encoding'], repl=row['emoji'], string=old_text)
            old_text = new_text
        else:
            pass
        if row['R_Encoding_lower'] in old_text:
            new_text = re.sub(pattern=row['R_Encoding_lower'], repl=row['emoji'], string=old_text)
            old_text = new_text
        else:
            pass
    return old_text


def show_chinese_step1(text, emoji_dataset):
    result1 = re.sub('\<u\+', '\\'+'u', text.lower())
    result2 = re.sub('\>', '', result1)
    all_chars = result2.split()
    new_all_chars = []
    for char in all_chars:
        emoji_in_char = False
        for emoji in list(emoji_dataset['emoji']):
            if emoji in char:
                emoji_in_char = True
                new_char = char.encode('utf-8').decode('utf-8')
                new_all_chars.append(new_char)
            else:
                pass
        if not emoji_in_char:
            new_char = char.encode('utf-8').decode('unicode_escape')
            new_all_chars.append(new_char)
    return " ".join(new_all_chars)


def show_chinese_step2(text):
    result1 = re.sub('<', '\\x', text)
    result2 = encode(result1.encode().decode('unicode_escape', 'ignore'), 'raw_unicode_escape')
    result3 = result2.decode('utf-8', 'ignore')
    return result3


def show_chinese_step3(text):
    patterns = re.findall(pattern='\\\\u[a-z0-9]{4}', string=text)
    old_text = text
    for pattern in patterns:
        new_pattern = pattern.encode('utf-8').decode('unicode_escape', 'ignore')
        new_text = re.sub(pattern='\\'+pattern, repl=new_pattern, string=old_text)
        old_text = new_text
    return old_text


text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['url', 'email', 'percent', 'money', 'phone', 'user',
               'time', 'url', 'date', 'number'],
    # terms that will be annotated
    annotate={"hashtag", "allcaps", "elongated", "repeated",
              'emphasis', 'censored'},
    fix_html=True,  # fix HTML tokens

    # corpus from which the word statistics are going to be used
    # for word segmentation
    segmenter="twitter",

    # corpus from which the word statistics are going to be used
    # for spell correction
    corrector="twitter",

    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words

    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,

    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)


def preprocessing_for_english(text_preprocessor, raw_text):
    preprocessed_text = ' '.join(text_preprocessor.pre_process_doc(str(raw_text)))
    # remove punctuations
    result = re.sub(u'[{}]'.format(string.punctuation), u'', preprocessed_text)
    return result


def clean_english_tweet_for_review(text, emoji_dictionary):
    text_with_emoji = show_emoji_in_tweet(text, emoji_dictionary)
    processed_text = preprocessing_for_english(text_processor, text_with_emoji)
    return processed_text


def clean_chinese_tweet_for_review(text, emoji_dictionary):
    tweet_with_emoji = show_emoji_in_tweet(text, emoji_dictionary)
    step1 = show_chinese_step1(tweet_with_emoji, emoji_dictionary)
    step2 = show_chinese_step2(step1)
    step3 = show_chinese_step3(step2)
    return step3
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %% [markdown]
# ### Load the emoji dataset in here:
# https://github.com/bright1993ff66/Social-Media-Data-Analysis/blob/master/Datasets/emoji.pkl

# %%
emoji_dict = pd.read_pickle(os.path.join(tweet_2017_path, 'emoji.pkl'))

# %% [markdown]
# ### Clean the English tweets

# %%
en_tweets_sample['cleaned_text'] = en_tweets_sample.apply(lambda row: clean_english_tweet_for_review(row['text'], emoji_dict),
                                        axis = 1)

# %%
en_tweets_sample = en_tweets_sample[['text', 'cleaned_text', 'url']]

# %%
en_tweets_sample
# Out:
#                                                   text  \
# 121  It's on! #ArtBaselHK #AlanCristeaGallery 1B30 ...
# 133  Some #streetfood to work up an appetite. í ½í¸...
# 117                            @chiewata take care bro
# 5    @akari_oozora Source: "Three statues" by yewen...
# 85   ASIA | AS â  China is pessimistic about Kore...
# 88   ASIA â China's Love-Hate Relationship With T...
# 179  I can't believe today's my last workout sessio...
# 314  Motto in HK day 2 #motto #gdragon #gdragonhkco...
# 10   How do you process human connection? Be yourse...
# 2    06:48 Temp. 22.9Â°C, Hum. 73%, Dewp. 16.7Â°C, ...
# 248  HKFP: Joint checkpoint plan âmost serious vi...
# 73   How fitting #heavydownpour on the feast of #St...
# 99   I'm at Ho Hung Kee in Causeway Bay https://t.c...
# 121  Starbucks <U+2764><ed><U+00A0><U+00BD><ed><U+0...
# 0    00:44 Temp. 18.4Â°C, Hum. 71%, Dewp. 11.9Â°C, ...
#
#                                           cleaned_text  \
# 121  it  s on  hashtag art basel hk hashtag hashtag...
# 133  some hashtag street food hashtag to work up an...
# 117                                 user take care bro
# 5    user source   three statues  by yewenyi on fli...
# 85   allcaps asia allcaps  as e2  number   number  ...
# 88   allcaps asia allcaps e2  number   number  chin...
# 179  i can not believe today  s my last workout ses...
# 314  motto in hk day number hashtag motto hashtag h...
# 10   how do you process human connection  be yourse...
# 2    time temp  number c2 b0 c  hum  percent  dewp ...
# 248  allcaps hkfp allcaps  joint checkpoint plan e2...
# 73   how fitting hashtag heavy downpour hashtag on ...
# 99             i am at ho hung kee in causeway bay url
# 121           starbucks  u  number  🐼  panda hotel url
# 0    time temp  number c2 b0 c  hum  percent  dewp ...
#
#                          url
# 121  https://t.co/2dgLXWGEpt
# 133  https://t.co/DdZE5YdE2f
# 117                      NaN
# 5    https://t.co/bzNRNCYiRB
# 85   https://t.co/A7DHzAJHTv
# 88   https://t.co/7aA5u5aodm
# 179  https://t.co/WHyDUGSIBj
# 314  https://t.co/5hvW7GPRWy
# 10   https://t.co/mUI6TnNvBa
# 2                        NaN
# 248  https://t.co/remTE3Slvi
# 73   https://t.co/pgZaefZb66
# 99   https://t.co/wo18j9ecPW
# 121  https://t.co/3vDBPa60hc
# 0                        NaN

# %% [markdown]
# ### Clean the Chinese tweets

# %%
zh_tweets_sample['cleaned_text'] = zh_tweets_sample.apply(lambda row: clean_chinese_tweet_for_review(row['text'], emoji_dict),
                                        axis = 1)

# %%
zh_tweets_sample = zh_tweets_sample[['text', 'cleaned_text', 'url']]

# %%
zh_tweets_sample
# Out:
#                                                   text  \
# 1    æäºäºæ
# ä¸æ¯æéå¯ä»¥æ²æ·¡â¯åå¹´ä...
# 134  Happy Easter!<U+5FA9><U+6D3B><U+7BC0><U+5FEB><...
# 256  #reuniondinner2017 #<U+5718><U+5E74><U+98EF>20...
# 51   Sai Kung Town â¢ Sai Kung, Hong Kong â¢ è¥¿è...
# 67   ç¹¼ä¸æ¬¡æå
# å¯¶çä¹å¾ï¼ä»æææå
# é...
# 136  <U+6930><U+5B50><U+70AD> &amp; 70% <U+7DA0><U+...
# 98   The price of dim sum in hkg í ½í±\n#onedimsum...
# 69   <U+6CD5><U+5F0F><U+5343><U+5C64><U+9165><U+86C...
# 115  I'm at Nina Tower å¦å¿å»£å ´ in Tsuen Wan ht...
# 13   Live Band çä¿åå¾é  #ê¹íì° #íì° #...
# 265  #<U+7121><U+795E><U+795E><U+56DB><U+570D><U+9A...
# 236  <U+5C31><U+60F3><U+5403><U+6E6F><U+5713><U+548...
# 170  é·è¤¸åºåæå°èªå·±èº«æææä¿¡å¿ @ H...
# 62   @miniyoshima @happynatalie @_lamdavid @uituit ...
# 84   #gathering #okonomiyaki @ éé å å¾¡å¥½ç-é...
#
#                                           cleaned_text  \
# 1    有些事情不是時間可以沖淡⋯十年了⋯心痛仍感受如初 @ 鑽石山墳埸思親堂 https://t....
# 134  happy easter!復活節快樂!#復活節要有復活蛋 @ 香港迪士尼樂園 | hong ...
# 256  #reuniondinner2017 #團年飯2017 @ 天后廟道 https://t.c...
# 51   sai kung town • sai kung, hong kong • 西貢市 • 香港...
# 67   繼上次月光寶盒之後，今晚有月光餅盒比大家頂住癮先。仲帶咗特別版既推石頭的人比大家! 最開心又...
# 136  椰子炭 &amp; 70% 綠茶雪糕 @ a fun store https://t.co/...
# 98   the price of dim sum in hkg 👌#onedimsum #dimsu...
# 69   法式千層酥蛋糕配士多啤梨雪糕。這是個非常符合港人口味和期望的「妹灰」,足可見樂師傅的心思。-...
# 115  i'm at nina tower 如心廣場 in tsuen wan https://t....
# 13   live band 真係冇得頂 #김태연 #태연 #sone #persona #hongk...
# 265  #無神神四圍騰 #streetcat #verytalkative #wonderfulco...
# 236  就想吃湯圓和芋圓吶,可偏偏就沒有🤣 @ 銅鑼灣 松記糖水店 https://t.co/ksk...
# 170  長褸出動時對自己身材最有信心 @ hong kong international airpo...
# 62   @miniyoshima @happynatalie @_lamdavid @uituit ...
# 84   #gathering #okonomiyaki @ 道頓堀御好燒-香港 https://t....
#
#                          url
# 1    https://t.co/C2vBDbADEJ
# 134  https://t.co/O43UcPb1VB
# 256  https://t.co/WcMxmEqY9I
# 51   https://t.co/JjzW6gKjaO
# 67   https://t.co/vMo4q0WClE
# 136  https://t.co/1ks5nnaOHX
# 98   https://t.co/9sT9uVeqVr
# 69   https://t.co/GzuwqjcG0X
# 115  https://t.co/teai9iAiV4
# 13   https://t.co/cLHY2ye0D5
# 265  https://t.co/llyXVAw74g
# 236  https://t.co/KSK0K4KcMX
# 170  https://t.co/fZw6T7OT1x
# 62                       NaN
# 84   https://t.co/WeMWM68Lg1

# %% [markdown]
# ### For the Chinese tweets, you could use Google Translate and translate them into English so that you could generate tweet representation
