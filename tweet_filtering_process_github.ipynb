# %%
import pandas as pd
import os
import numpy as np
import csv
import pytz
import time
from datetime import datetime
from collections import Counter

import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# A package which could be used to check whether an account is a bot
import botometer

import matplotlib.pyplot as plt

# %%
tweet_2017_path_raw = r'XXXX'
tweet_2016_path_raw = r'XXXXX'
desktop = r'XXXXX'
# saving_path = r'F:\CityU\Datasets'
tweet_filtering_path =  r'XXXXX'
bot_check_path =  r'XXXXX'
bot_check_figure_path =  r'XXXXX'


# Hong Kong and Shanghai share the same time zone.
# Hence, we transform the utc time in our dataset into Shanghai time
time_zone_hk = pytz.timezone('Asia/Shanghai')

# %%
# pd.set_option('display.precision', 18)

# %%
# Set some account information
# For more details, please go to: https://github.com/IUNetSci/botometer-python
mashape_key = "XXXXXX"
twitter_app_auth = {
    'consumer_key': "XXXXXX",
    'consumer_secret': "XXXXXX",
    'access_token': "XXXXXX",
    'access_token_secret': "XXXXXX",
  }
bom = botometer.Botometer(wait_on_ratelimit=True,
                          mashape_key=mashape_key,
                          **twitter_app_auth)

auth = OAuthHandler("XXXXXX", "XXXXXX")

auth.set_access_token("XXXXXX", "XXXXXX")

api = tweepy.API(auth)

# Construct the API instance
api = tweepy.API(auth)

# %% [markdown]
# ## 1. Load some functions

# %%
# read multiple csv files from a local directory
def read_text_from_multi_csvs(path):
    all_csv_files = os.listdir(path)
    dataframes = []
    for file in all_csv_files:
        dataframe = pd.read_csv(os.path.join(path, file), encoding='latin-1', dtype='str', 
                                quoting=csv.QUOTE_NONNUMERIC)
        dataframes.append(dataframe)
    combined_dataframes = pd.concat(dataframes, sort=True)
    return combined_dataframes

def read_local_csv_file(path, filename):
    dataframe = pd.read_csv(os.path.join(path, filename), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC, dtype='str', 
                            index_col=0)
    return dataframe

# Function used to output a pandas dataframe for each user based on the user account number
def derive_dataframe_for_each_user(df, all_users):
    dataframes = []
    print('Total number of users is {}'.format(len(all_users)))
    count = 1
    for user in all_users:
        if count % 1000 == 0:
            print('The first {} users have been processed'.format(count))
        dataframes.append(df.loc[df['user_id_str']==user])
        count += 1
    print('Done!')
    return dataframes

# Based on the dataframe for each user, compute the time range between his or her first tweet and last tweet
def compute_time_range_for_one_user(df):
    user_id_str = list(df['user_id_str'])[0]
    first_row_time_object = list(df.head(1)['hk_time'])[0]
    end_row_time_object = list(df.tail(1)['hk_time'])[0]
    time_range = end_row_time_object - first_row_time_object
    return (user_id_str, time_range.days)

# Add a new colume named hk_time
def get_hk_time(df):
    changed_time_list = []
    for _, row in df.iterrows():
        time_to_change = datetime.strptime(row['created_at'], '%a %b %d %H:%M:%S %z %Y')
        # get the hk time
        changed_time = time_to_change.astimezone(time_zone_hk)
        changed_time_list.append(changed_time)
    df['hk_time'] = changed_time_list
    return df

# Output 
def number_of_tweet_user(df):
    user_num = len(set(df['user_id_str']))
    tweet_num = df.shape[0]
    print('Total number of tweet is: {}; Total number of user is {}'.format(
        tweet_num, user_num))

# %%
def delete_bots_have_same_geoinformation(df, prop_threshold=0.70):
    users = set(list(df['user_id_str']))
    bot_account = []
    for user in users:
        dataframe = df.loc[df['user_id_str']==user]
        lat_counter = Counter(dataframe['lat'])
        lon_counter = Counter(dataframe['lon'])
        decide = (compute_the_highest_proportion_from_counter(lat_counter, prop_threshold)) or (compute_the_highest_proportion_from_counter(lon_counter, prop_threshold))
        # If only one unqiue geoinformation is found and more than 10 tweets are posted, we regard this account as bot
        if decide:
            bot_account.append(user)
        else:
            pass
    print('Done!')
    cleaned_df = df.loc[~df['user_id_str'].isin(bot_account)]
#     cleaned_df.to_pickle(os.path.join(saving_path, file_name))
    return cleaned_df

def compute_the_highest_proportion_from_counter(counter_dict, prop_threshold):
    total_count = sum(counter_dict.values())
    result = False
    for latitude in list(counter_dict.keys()):
        if counter_dict[latitude]/total_count > prop_threshold:
            result = True
            return result
        else:
            pass
    return result

def compute_tweet_num_geo_prop(df):
    user_set = set(df['user_id_str'])
    result_list = []
    for user in user_set:
        user_dataframe = df.loc[df['user_id_str'] == user]
        tweet_num = user_dataframe.shape[0]
        prop_num_lat = max(list(Counter(user_dataframe['lat']).values()))/sum(Counter(user_dataframe['lat']).values())
        prop_num_lon = max(list(Counter(user_dataframe['lon']).values()))/sum(Counter(user_dataframe['lon']).values())
        prop_num = max(prop_num_lat, prop_num_lon)
        result_list.append((tweet_num, prop_num))
    return result_list

# %%
def find_unuseful_geoinformation(df):
    wrong_list = []
    for _, row in df.iterrows():
        try:
            float(row['lat'])
        except:
            wrong_list.append(row['lat'])
    return wrong_list

# %%
def check_bot(id_str):
    result = bom.check_account(id_str)
    return result['cap']['universal']

# %%
# plot cumulative distribution of a list of values
def plot_cumulative(number_list, bin_num, color, title, xlabel, ylabel, saving_path, file_name):
    
    fig, ax = plt.subplots(1,1,figsize=(10,10), dpi=300)
    
    values, base = np.histogram(number_list, bins=bin_num)
    #evaluate the cumulative
    cumulative = np.cumsum(values)
    # plot the cumulative function

    plt.plot(base[:-1], cumulative, c=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    fig.savefig(os.path.join(saving_path, file_name))
    plt.show()

# %% [markdown]
# ## 2. Read from local files

# %%
combined_dataframe_2017 = read_text_from_multi_csvs(tweet_2017_path_raw)

# %%
combined_dataframe_2016 = read_text_from_multi_csvs(tweet_2016_path_raw)

# %%
combined_dataframe_2017.shape
# Out:
# (1602627, 44)

# %%
combined_dataframe_2016.shape
# Out:
# (1281281, 43)

# %%
selected_name_list = ['country', 'country_code', 'created_at', 'description',
       'expanded_url', 'favorited', 'favourites_count',
       'followers_count', 'friends_count', 'full_name', 'geo_enabled',
       'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id_str',
       'in_reply_to_user_id_str', 'lang', 'lat', 'listed_count', 'location',
       'lon', 'name', 'place_id', 'place_lat', 'place_lon', 'place_name',
       'place_type', 'protected', 'retweet_count', 'retweeted', 'screen_name',
       'source', 'statuses_count', 'text', 'time_zone', 'truncated', 'url',
       'user_created_at', 'user_id_str', 'user_lang', 'user_url', 'utc_offset',
       'verified']
len(selected_name_list)
# Out:
# 42

# %%
combined_dataframe_2016 = combined_dataframe_2016[selected_name_list]

# %%
combined_dataframe_2017 = combined_dataframe_2017[selected_name_list]

# %%
total_dataframe = pd.concat([combined_dataframe_2017, combined_dataframe_2016], sort=True, axis=0)

# %%
number_of_tweet_user(total_dataframe)
# Out:
# Total number of tweet is: 2883908; Total number of user is 179022

# %% [markdown]
# ## 3. Some initial steps
#
# 1. Only consider the English and Chinese tweets
# 2. Remove the verified accounts
# 3. Only consider the tweets have geoinformation

# %%
total_dataframe_zh_en = total_dataframe.loc[total_dataframe['lang'].isin(['zh', 'en'])]
total_dataframe_zh_en.shape
# Out:
# (1703742, 42)

# %%
number_of_tweet_user(total_dataframe_zh_en)
# Out:
# Total number of tweet is: 1703742; Total number of user is 133377

# %%
total_dataframe_without_verified = total_dataframe_zh_en.loc[total_dataframe_zh_en['verified'].isin(['FALSE'])]
total_dataframe_without_verified.shape
# Out:
# (1648379, 42)

# %%
number_of_tweet_user(total_dataframe_without_verified)
# Out:
# Total number of tweet is: 1648379; Total number of user is 131712

# %%
total_dataframe_with_geo = total_dataframe_without_verified.dropna(axis=0, subset=['lat'])
total_dataframe_with_geo.shape
# Out:
# (554921, 42)

# %%
number_of_tweet_user(total_dataframe_with_geo)
# Out:
# Total number of tweet is: 554921; Total number of user is 60860

# %% [markdown]
# ## 4. Remove visitors
#
# First, change the time to Hong Kong time

# %%
total_dataframe_with_geo_copy = total_dataframe_with_geo.copy()
total_dataframe_with_hk_time = get_hk_time(total_dataframe_with_geo_copy)

# %%
# %%time
total_dataframe_with_hk_time['year'] = total_dataframe_with_hk_time.apply(lambda row: int(row['hk_time'].year), axis=1)
total_dataframe_with_hk_time['month'] = total_dataframe_with_hk_time.apply(lambda row: int(row['hk_time'].month), axis=1)
total_dataframe_with_hk_time['month_plus_year'] = total_dataframe_with_hk_time.apply(
    lambda row: str(row['year'])+'_'+str(row['month']), axis=1)

# %%
total_dataframe_with_hk_time.head(10)[['user_id_str', 'created_at', 'hk_time', 'year', 'month', 'month_plus_year']]
# Out:
#    user_id_str                      created_at                   hk_time  \
# 8     29760327  Sat Dec 31 15:29:07 +0000 2016 2016-12-31 23:29:07+08:00
# 9   1130930804  Sat Dec 31 15:29:08 +0000 2016 2016-12-31 23:29:08+08:00
# 13    74768210  Sat Dec 31 15:30:00 +0000 2016 2016-12-31 23:30:00+08:00
# 31    96368749  Sat Dec 31 15:31:32 +0000 2016 2016-12-31 23:31:32+08:00
# 33  3018108065  Sat Dec 31 15:31:46 +0000 2016 2016-12-31 23:31:46+08:00
# 46    52745573  Sat Dec 31 15:32:46 +0000 2016 2016-12-31 23:32:46+08:00
# 51   111903594  Sat Dec 31 15:33:01 +0000 2016 2016-12-31 23:33:01+08:00
# 54    96273306  Sat Dec 31 15:33:19 +0000 2016 2016-12-31 23:33:19+08:00
# 57   149424044  Sat Dec 31 15:33:37 +0000 2016 2016-12-31 23:33:37+08:00
# 61   262445623  Sat Dec 31 15:33:59 +0000 2016 2016-12-31 23:33:59+08:00
#
#     year  month month_plus_year
# 8   2016     12         2016_12
# 9   2016     12         2016_12
# 13  2016     12         2016_12
# 31  2016     12         2016_12
# 33  2016     12         2016_12
# 46  2016     12         2016_12
# 51  2016     12         2016_12
# 54  2016     12         2016_12
# 57  2016     12         2016_12
# 61  2016     12         2016_12

# %% [markdown]
# Sort the dataframe based on the ```hk_time``` column

# %%
total_dataframe_with_hk_time_sorted = total_dataframe_with_hk_time.sort_values(by='hk_time')

# %%
total_dataframe_with_hk_time_sorted.sample(10)[['user_id_str', 'created_at', 'hk_time', 'year', 'month', 'month_plus_year']]
# Out:
#             user_id_str                      created_at  \
# 50            149585330  Tue Aug 15 14:11:34 +0000 2017
# 214  732398699108687872  Wed May 18 02:14:16 +0000 2016
# 36            789378074  Thu Jun 08 10:10:11 +0000 2017
# 35             55845103  Wed Jun 15 20:48:26 +0000 2016
# 210            28814305  Fri Sep 23 13:49:51 +0000 2016
# 207           240981263  Fri Jun 17 05:02:12 +0000 2016
# 27            390048445  Mon Jan 16 06:31:24 +0000 2017
# 228           190875987  Fri Jun 09 06:59:17 +0000 2017
# 8    774694926135222272  Sun Jan 01 09:30:03 +0000 2017
# 177           109767776  Fri Dec 29 10:48:19 +0000 2017
#
#                       hk_time  year  month month_plus_year
# 50  2017-08-15 22:11:34+08:00  2017      8          2017_8
# 214 2016-05-18 10:14:16+08:00  2016      5          2016_5
# 36  2017-06-08 18:10:11+08:00  2017      6          2017_6
# 35  2016-06-16 04:48:26+08:00  2016      6          2016_6
# 210 2016-09-23 21:49:51+08:00  2016      9          2016_9
# 207 2016-06-17 13:02:12+08:00  2016      6          2016_6
# 27  2017-01-16 14:31:24+08:00  2017      1          2017_1
# 228 2017-06-09 14:59:17+08:00  2017      6          2017_6
# 8   2017-01-01 17:30:03+08:00  2017      1          2017_1
# 177 2017-12-29 18:48:19+08:00  2017     12         2017_12

# %%
len(set(total_dataframe_with_hk_time_sorted['user_id_str']))
# Out:
# 60860

# %% [markdown]
# Then, we remove the visitors. Here we only consider the people of which the time range between the first tweet and the last tweet is bigger than 7 days
#
# **Note**: we notice that some visitors, such as Japanese, could stay in Hong Kong for 14 days.

# %%
all_users = set(total_dataframe_with_hk_time_sorted['user_id_str'])
dataframes = derive_dataframe_for_each_user(total_dataframe_with_hk_time_sorted, all_users)
# Out:
# Total number of users is 60860
# The first 1000 users have been processed
# The first 2000 users have been processed
# The first 3000 users have been processed
# The first 4000 users have been processed
# The first 5000 users have been processed
# The first 6000 users have been processed
# The first 7000 users have been processed
# The first 8000 users have been processed
# The first 9000 users have been processed
# The first 10000 users have been processed
# The first 11000 users have been processed
# The first 12000 users have been processed
# The first 13000 users have been processed
# The first 14000 users have been processed
# The first 15000 users have been processed
# The first 16000 users have been processed
# The first 17000 users have been processed
# The first 18000 users have been processed
# The first 19000 users have been processed
# The first 20000 users have been processed
# The first 21000 users have been processed
# The first 22000 users have been processed
# The first 23000 users have been processed
# The first 24000 users have been processed
# The first 25000 users have been processed
# The first 26000 users have been processed
# The first 27000 users have been processed
# The first 28000 users have been processed
# The first 29000 users have been processed
# The first 30000 users have been processed
# The first 31000 users have been processed
# The first 32000 users have been processed
# The first 33000 users have been processed
# The first 34000 users have been processed
# The first 35000 users have been processed
# The first 36000 users have been processed
# The first 37000 users have been processed
# The first 38000 users have been processed
# The first 39000 users have been processed
# The first 40000 users have been processed
# The first 41000 users have been processed
# The first 42000 users have been processed
# The first 43000 users have been processed
# The first 44000 users have been processed
# The first 45000 users have been processed
# The first 46000 users have been processed
# The first 47000 users have been processed
# The first 48000 users have been processed
# The first 49000 users have been processed
# The first 50000 users have been processed
# The first 51000 users have been processed
# The first 52000 users have been processed
# The first 53000 users have been processed
# The first 54000 users have been processed
# The first 55000 users have been processed
# The first 56000 users have been processed
# The first 57000 users have been processed
# The first 58000 users have been processed
# The first 59000 users have been processed
# The first 60000 users have been processed
# Done!

# %%
time_range_list = []

for df in dataframes:
    # Each value in time_range_list contains the user_id_str and the maximum time range betweet the first
    # tweet and the last tweet
    time_range_list.append(compute_time_range_for_one_user(df))

locals = []

for day in time_range_list:
    if day[1] > 7:
        locals.append(day[0])

local_dataframe = total_dataframe_with_hk_time_sorted.loc[total_dataframe_with_hk_time_sorted['user_id_str'].isin(locals)]

# %%
number_of_tweet_user(local_dataframe)
# Out:
# Total number of tweet is: 451353; Total number of user is 18752

# %% [markdown]
# ## 5. Get the dataset for tweet 2016 and tweet 2017 seperately

# %%
dataframe_2016 = local_dataframe.loc[local_dataframe['year'] == 2016]
dataframe_2017 = local_dataframe.loc[local_dataframe['year'] == 2017]

# Some geoinformation of rows is not useful enough
wrong_list_2016 = find_unuseful_geoinformation(dataframe_2016)
wrong_list_2017 = find_unuseful_geoinformation(dataframe_2017)

# %%
print(wrong_list_2016, wrong_list_2017)
# Out:
# ['https://www.instagram.com/p/BFGklyqhaVb/', 'https://www.instagram.com/p/BFGli0tlrVC/'] []

# %%
dataframe_2016_cleaned = dataframe_2016.loc[~dataframe_2016['lat'].isin(wrong_list_2016)]

# %%
dataframe_2016_cleaned.shape
# Out:
# (184390, 46)

# %%
dataframe_2016_cleaned_copy = dataframe_2016_cleaned.copy()
dataframe_2017_copy = dataframe_2017.copy()

# %%
dataframe_2016_cleaned_copy[["lat", "lon"]] = dataframe_2016_cleaned_copy[["lat", "lon"]].astype(np.float64)
dataframe_2017_copy[["lat", "lon"]] = dataframe_2017_copy[["lat", "lon"]].astype(np.float64)

# %%
dataframe_2017_copy.to_csv(os.path.join(desktop, 'tweet_data_2017.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)
dataframe_2016_cleaned_copy.to_csv(os.path.join(desktop, 'tweet_data_2016.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)

# %%
# check the user_id_str column
# dataframe_2017_check = pd.read_csv(os.path.join(desktop, 'tweet_data_2017.csv'), encoding='utf-8', 
#                                    quoting=csv.QUOTE_NONNUMERIC, dtype='str')
# list(set(dataframe_2017_check['user_id_str']))

# %% [markdown]
# ### Save the user_id_str list and pass other columns to the ArcMap

# %%
dataframe_2016_id = np.array(list(dataframe_2016_cleaned_copy['user_id_str']))
dataframe_2017_id = np.array(list(dataframe_2017_copy['user_id_str']))

# %%
np.save(os.path.join(desktop, 'tweet_2016_ids.npy'), dataframe_2016_id)
np.save(os.path.join(desktop, 'tweet_2017_ids.npy'), dataframe_2017_id)

# %% [markdown]
# ### Load the datasets, which could be used in the following sections

# %%
dataframe_2016_cleaned = read_local_csv_file(path=desktop, filename='tweet_data_2016.csv')
dataframe_2017 = read_local_csv_file(path=desktop, filename='tweet_data_2017.csv')

# %% [markdown]
# ### Save the latitude and longitude information, which could be passed to the ArcMap

# %%
dataframe_2016_geoinfo = dataframe_2016_cleaned[['lat', 'lon']]
dataframe_2017_geoinfo = dataframe_2017[['lat', 'lon']]

# %% [markdown]
# The ArcMap will shuffle the rows randomly. We should add a column named ```index``` before passing to ArcMap. This could help us keep the order of the dataset

# %%
dataframe_2016_geoinfo_copy = dataframe_2016_geoinfo.copy()
dataframe_2016_geoinfo_copy['index'] = list(range(dataframe_2016_geoinfo_copy.shape[0]))

# %%
dataframe_2017_geoinfo_copy = dataframe_2017_geoinfo.copy()
dataframe_2017_geoinfo_copy['index'] = list(range(dataframe_2017_geoinfo_copy.shape[0]))

# %%
dataframe_2016_geoinfo_copy.to_csv(os.path.join(desktop, 'tweet_2016_geoinfo.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)
dataframe_2017_geoinfo_copy.to_csv(os.path.join(desktop, 'tweet_2017_geoinfo.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)

# %%
dataframe_2017_geoinfo_copy.head(10)
# Out:
#              lat          lon  index
# 340  22.21628624  114.2487221      0
# 348  22.28167335  114.1552205      1
# 355  22.40605926   114.224178      2
# 363  22.20283915  113.5396544      3
# 366  22.20777778  114.2605556      4
# 380  22.29453165  114.1685411      5
# 400  23.11891092  113.3219467      6
# 404  22.31307492  114.0438768      7
# 408  22.32375913  114.1730004      8
# 416  22.73647885  114.2477163      9

# %% [markdown]
# ## 6. Use ArcMap to find tweets in Hong Kong
#
# First, we should replace the ```user_id_str``` column with the corresponding saved array. Because the ArcMap automatically transform the type of ```user_id_str``` column from string to numeric, which may lose some digits if the id is too long
#
# Then, we should load the geoinformation recorded in the processed ```dataframe_2016_geoinfo``` and ```dataframe_2017_geoinfo```
#
# Load the processed datasets first

# %%
# Load the dataset which contains the geoinformation'
tweet_2016_tpu_geo = read_local_csv_file(path=desktop, filename='tweet_2016_with_tpuinfo.csv')
tweet_2017_tpu_geo = read_local_csv_file(path=desktop, filename='tweet_2017_with_tpuinfo.csv')

# %% [markdown]
# Then order the dataset based on the predefined index. The index in ```tweet_2016_tpu_geo``` dataframe is ```user_id_st``` while the index in ```tweet_2017_tpu_geo``` is ```index```.

# %%
tweet_2017_tpu_geo.columns
# Out:
# Index(['Field1', 'lat', 'lon', 'index', 'FID_2', 'FID_1_1', 'merge_Nums',
#        'SmallTPU'],
#       dtype='object')

# %%
tweet_2016_tpu_geo[["user_id_st", 'lat', 'lon']] = tweet_2016_tpu_geo[["user_id_st", 'lat', 'lon']].astype(np.float64)
tweet_2017_tpu_geo[["index", 'lat', 'lon']] = tweet_2017_tpu_geo[["index", 'lat', 'lon']].astype(np.float64)

# %%
# Then order the data based on the corresponding index
tweet_2016_tpu_geo_copy = tweet_2016_tpu_geo.copy()
tweet_2016_tpu_geo_sorted = tweet_2016_tpu_geo_copy.sort_values(by='user_id_st')
tweet_2017_tpu_geo_copy = tweet_2017_tpu_geo.copy()
tweet_2017_tpu_geo_sorted = tweet_2017_tpu_geo_copy.sort_values(by='index')

# %% [markdown]
# **!!! Add the TPU information and the ids to the dataframe!!!**

# %%
tweet_2016_tpu = list(tweet_2016_tpu_geo_sorted['SmallTPU'])
tweet_2017_tpu = list(tweet_2017_tpu_geo_sorted['SmallTPU'])
tweet_2016_ids = np.load(os.path.join(desktop, 'tweet_2016_ids.npy'))
tweet_2017_ids = np.load(os.path.join(desktop, 'tweet_2017_ids.npy'))

# %%
dataframe_2017['user_id_str'] = tweet_2017_ids
dataframe_2017['SmallTPU'] = tweet_2017_tpu
dataframe_2016_cleaned['user_id_str'] = tweet_2016_ids
dataframe_2016_cleaned['SmallTPU'] = tweet_2016_tpu

# %%
dataframe_2017.head(10)[['user_id_str', 'created_at', 'hk_time', 'lat', 'lon', 'SmallTPU']]
# Out:
#     user_id_str                      created_at                    hk_time  \
# 340   106942703  Sat Dec 31 16:00:03 +0000 2016  2017-01-01 00:00:03+08:00
# 348  2892511442  Sat Dec 31 16:00:10 +0000 2016  2017-01-01 00:00:10+08:00
# 355  4053994772  Sat Dec 31 16:00:25 +0000 2016  2017-01-01 00:00:25+08:00
# 363    14282045  Sat Dec 31 16:00:46 +0000 2016  2017-01-01 00:00:46+08:00
# 366    90582376  Sat Dec 31 16:00:55 +0000 2016  2017-01-01 00:00:55+08:00
# 380  1130930804  Sat Dec 31 16:01:50 +0000 2016  2017-01-01 00:01:50+08:00
# 400   306524050  Sat Dec 31 16:02:40 +0000 2016  2017-01-01 00:02:40+08:00
# 404  1130930804  Sat Dec 31 16:02:49 +0000 2016  2017-01-01 00:02:49+08:00
# 408    67074845  Sat Dec 31 16:02:59 +0000 2016  2017-01-01 00:02:59+08:00
# 416    10065202  Sat Dec 31 16:03:19 +0000 2016  2017-01-01 00:03:19+08:00
#
#              lat          lon   SmallTPU
# 340  22.21628624  114.2487221        197
# 348  22.28167335  114.1552205  121 & 122
# 355  22.40605926   114.224178        757
# 363  22.20283915  113.5396544        NaN
# 366  22.20777778  114.2605556        197
# 380  22.29453165  114.1685411        211
# 400  23.11891092  113.3219467        NaN
# 404  22.31307492  114.0438768    971-974
# 408  22.32375913  114.1730004        222
# 416  22.73647885  114.2477163        NaN

# %% [markdown]
# Load the previous unprocessed file. Check the ids and lat, lons

# %%
check_2017 = read_local_csv_file(path=desktop, filename='tweet_data_2017.csv')
check_2017.head(10)[['user_id_str', 'created_at', 'hk_time', 'lat', 'lon']]
# Out:
#     user_id_str                      created_at                    hk_time  \
# 340   106942703  Sat Dec 31 16:00:03 +0000 2016  2017-01-01 00:00:03+08:00
# 348  2892511442  Sat Dec 31 16:00:10 +0000 2016  2017-01-01 00:00:10+08:00
# 355  4053994772  Sat Dec 31 16:00:25 +0000 2016  2017-01-01 00:00:25+08:00
# 363    14282045  Sat Dec 31 16:00:46 +0000 2016  2017-01-01 00:00:46+08:00
# 366    90582376  Sat Dec 31 16:00:55 +0000 2016  2017-01-01 00:00:55+08:00
# 380  1130930804  Sat Dec 31 16:01:50 +0000 2016  2017-01-01 00:01:50+08:00
# 400   306524050  Sat Dec 31 16:02:40 +0000 2016  2017-01-01 00:02:40+08:00
# 404  1130930804  Sat Dec 31 16:02:49 +0000 2016  2017-01-01 00:02:49+08:00
# 408    67074845  Sat Dec 31 16:02:59 +0000 2016  2017-01-01 00:02:59+08:00
# 416    10065202  Sat Dec 31 16:03:19 +0000 2016  2017-01-01 00:03:19+08:00
#
#              lat          lon
# 340  22.21628624  114.2487221
# 348  22.28167335  114.1552205
# 355  22.40605926   114.224178
# 363  22.20283915  113.5396544
# 366  22.20777778  114.2605556
# 380  22.29453165  114.1685411
# 400  23.11891092  113.3219467
# 404  22.31307492  114.0438768
# 408  22.32375913  114.1730004
# 416  22.73647885  114.2477163

# %% [markdown]
# ### They are matched!

# %% [markdown]
# For tweets not posted in Hong Kong, the ```SmallTPU``` column should be nan

# %%
tweet_2017_hk = dataframe_2017.dropna(axis=0, subset=['SmallTPU'])
tweet_2016_hk = dataframe_2016_cleaned.dropna(axis=0, subset=['SmallTPU'])

# %%
tweet_2017_hk.shape
# Out:
# (192192, 47)

# %%
tweet_2016_hk.shape
# Out:
# (136866, 47)

# %% [markdown]
# Save the files to the local directory

# %%
tweet_2016_hk.to_csv(os.path.join(desktop, 'tweet_2016_hk.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)
tweet_2017_hk.to_csv(os.path.join(desktop, 'tweet_2017_hk.csv'), encoding='utf-8', quoting=csv.QUOTE_NONNUMERIC)

# %%
# %%time
total_2016_2017 = pd.concat([tweet_2016_hk, tweet_2017_hk], axis=0)
print(total_2016_2017.shape)
# Out:
# (329058, 47)
# Wall time: 202 ms

# %%
number_of_tweet_user(total_2016_2017)
# Out:
# Total number of tweet is: 329058; Total number of user is 15974

# %% [markdown]
# Draw the cumulative distribution plot showing the number of tweets and geoinformation proportion

# %%
# %%time
tweet_num_geo_prop_list = compute_tweet_num_geo_prop(total_2016_2017)
print(tweet_num_geo_prop_list[:5])
# Out:
# [(5, 0.2), (2, 0.5), (3, 0.3333333333333333), (24, 0.08333333333333333), (2, 0.5)]
# Wall time: 6min 33s

# %%
count_list = [value[0] for value in tweet_num_geo_prop_list]
prop_list = [value[1] for value in tweet_num_geo_prop_list]

# %%
plot_cumulative(number_list=count_list, bin_num=40, color='red', title='Cumulative Distribution Tweet Number', 
                xlabel='Number of Posted Tweets', ylabel='Number of Users', saving_path=bot_check_figure_path, 
                file_name='Cumulative_dist_tweet_num.png')

# %%
plot_cumulative(number_list=prop_list, bin_num=40, color='green', title='Cumulative Distribution Geoinfo Proportion', 
                xlabel='Geoinfo Proportion', ylabel='Number of Users', saving_path=bot_check_figure_path, 
                file_name='Cumulative_dist_geo_prop.png')

# %% [markdown]
# ## 7. Delete the bots
#
# **First**, use my own function

# %%
tweet_2017_without_bot = delete_bots_have_same_geoinformation(tweet_2017_hk)
# Out:
# Done!

# %%
number_of_tweet_user(tweet_2017_without_bot)
# Out:
# Total number of tweet is: 140540; Total number of user is 8604

# %%
tweet_2016_without_bot = delete_bots_have_same_geoinformation(tweet_2016_hk)
# Out:
# Done!

# %%
number_of_tweet_user(tweet_2016_without_bot)
# Out:
# Total number of tweet is: 117790; Total number of user is 7686

# %% [markdown]
# **Second**, use the botometer to filter the tweet

# %%
tweet_2017_users_list = list(set(tweet_2017_without_bot['user_id_str']))
tweet_2016_users_list = list(set(tweet_2016_without_bot['user_id_str']))

# %%
tweet_all_users = set(tweet_2017_users_list + tweet_2016_users_list)
len(tweet_all_users)
# Out:
# 13124

# %%
print('Check bots starts....')
bot_result_list = []
processed_account_list = []
account_with_error = []
accounts = list(tweet_all_users)
# The input of the check bot function should be integers
account_integers = [int(number) for number in accounts]
# Get a set of unique users and transform it to list
account_integer_set_list = list(set(account_integers))
account_integer_set_string_list = [str(num) for num in account_integer_set_list]
# Out:
# Check bots starts....

# %%
for index, user in enumerate(account_integer_set_list):
    print('-----------------------------------------------')
    print("Coping with the ", index+1, 'th user: ', user)
    try:
        bot_result_list.append(check_bot(int(user)))
        processed_account_list.append(user)
        print('This account could be processed...')
        print('-----------------------------------------------')
    except Exception as e:
        # In this case, the api shows that this page is not authorized or does not exit
        # We record these accouts as Not Authorized in the bot_result_list
        bot_result_list.append('Not Authorized')
        processed_account_list.append(user)
        account_with_error.append(user)
        print('This account has some problem...')
        print('-----------------------------------------------')
    assert len(processed_account_list) == len(bot_result_list)
    if ((index+1) % 1000 == 0):
        print('The first {} users have been processed'.format(index+1))
        print('Have a break!')
        # You **MUST** specify the dtype='str' here  
        check_bot_dataframe = pd.DataFrame({'account':processed_account_list, 'bot_score': bot_result_list}, dtype='str')
        check_bot_dataframe.to_pickle(os.path.join(bot_check_path, 'bot_check_first_{}.pkl'.format(index+1)))
        time.sleep(30) # sleep for 30 seconds
        print('I am OK now!')
    else:
        pass
    
final_bot_likelihood_dataframe = pd.DataFrame({'account':processed_account_list, 'bot_score': bot_result_list}, dtype='str')
final_bot_likelihood_dataframe.to_pickle(os.path.join(bot_check_path, 'final_bot_check.pkl'))
# Out:
# -----------------------------------------------
# Coping with the  1 th user:  821611860646592512
# This account has some problem...
# -----------------------------------------------
# -----------------------------------------------
# Coping with the  2 th user:  756464839426310145
# This account could be processed...
# -----------------------------------------------
# -----------------------------------------------
# Coping with the  3 th user:  792055202039889920
# This account could be processed...
# -----------------------------------------------
# -----------------------------------------------
# Coping with the  4 th user:  736792813707231233
# This account could be processed...
# -----------------------------------------------
# -----------------------------------------------
# Coping with the  5 th user:  798444796213723136
# This account could be processed...
# -----------------------------------------------
# The first 5 users have been processed
# Have a break!
# I am OK now!

# %% [markdown]
# The computer has shut down! check the unprocessed accounts!

# %%
get_processed_dataframe = pd.read_csv(os.path.join(bot_check_path, 'bot_check_first_3000.csv'), encoding='utf-8', dtype='str', 
                                quoting=csv.QUOTE_NONNUMERIC)

# %%
get_processed_list = list(get_processed_dataframe['account'])

# %% [markdown]
# Get unprocessed list

# %%
get_unprocessed_list = list(set(account_integer_set_string_list) - set(get_processed_list))

# %%
len(get_unprocessed_list)
# Out:
# 10124

# %%
print(processed_account_list, bot_result_list, account_with_error)
# Out:
# [] [] []

# %% [markdown]
# Use the following codes to check the unprocessed accounts
#
# ```Python
# print('We still have {} users left'.format(len(get_unprocessed_list)))
#
# for index, user in enumerate(get_unprocessed_list):
#     print('-----------------------------------------------')
#     print("Coping with the ", index+1, 'th user: ', user)
#     try:
#         bot_result_list.append(check_bot(int(user)))
#         processed_account_list.append(user)
#         print('This account could be processed...')
#         print('-----------------------------------------------')
#     except Exception as e:
#         # In this case, the api shows that this page is not authorized or does not exit
#         # We record these accouts as Not Authorized in the bot_result_list
#         bot_result_list.append('Not Authorized')
#         processed_account_list.append(user)
#         print('This account has some problem...')
#         print('-----------------------------------------------')
#     assert len(processed_account_list) == len(bot_result_list)
#     if ((index+1) % 1000 == 0):
#         print('The first {} users have been processed'.format(index+1))
#         print('Have a break!')
#         # You **MUST** specify the dtype='str' here
#         check_bot_dataframe = pd.DataFrame({'account':processed_account_list, 'bot_score': bot_result_list}, dtype='str')
#         check_bot_dataframe.to_csv(os.path.join(bot_check_path, 'bot_check_second_first_{}.csv'.format(index+1)))
#         time.sleep(30) # sleep for 30 seconds
#         print('I am OK now!')
#     else:
#         pass
#
# final_bot_likelihood_second_dataframe = pd.DataFrame({'account':processed_account_list, 'bot_score': bot_result_list}, dtype='str')
# final_bot_likelihood_second_dataframe.to_csv(os.path.join(bot_check_path, 'final_bot_check.csv'), encoding='utf-8')
# ```

# %% [markdown]
# ### Finished! Load all the bot likelihood results

# %%
first_bot_file = read_local_csv_file(path=bot_check_path, filename='bot_check_first_3000.csv')
second_bot_file = read_local_csv_file(path=bot_check_path, filename='final_bot_check.csv')

# %%
combined_bot_file = pd.concat([first_bot_file, second_bot_file], axis=0)

# %%
combined_bot_file.shape
# Out:
# (13124, 2)

# %%
combined_bot_file.to_csv(os.path.join(bot_check_path, 'bot_likelihood_2016_2017.csv'), encoding='utf-8')

# %%
combined_bot_file.head()
# Out:
#               account            bot_score
# 0  792055202039889920   0.7086116865750549
# 1  750147280754409472  0.01645230483113907
# 2  774891096358780928  0.04861529098537897
# 3  756464839426310145  0.13065598435976788
# 4  729247315148439552       Not Authorized

# %%
decision_without_not_authorized = (combined_bot_file['bot_score'] != 'Not Authorized')
check_bot_dataframe = combined_bot_file.loc[decision_without_not_authorized]

# %%
without_not_authorized = [float(i) for i in list(check_bot_dataframe['bot_score'])]
plot_cumulative(number_list=without_not_authorized, bin_num=40, color='blue', 
                title='Cumulative Distribution of BOT Likelihood Score', xlabel='BOT Likelihood Score', 
                ylabel='Number of Users', saving_path=bot_check_figure_path, 
                file_name='Cumulative_dist_bot_likelihood_score.png')

# %% [markdown]
# 0.4 is a good cut-off value

# %%
check_bot_dataframe_copy = check_bot_dataframe.copy()
check_bot_dataframe_copy['bot_score'] = check_bot_dataframe_copy['bot_score'].astype('float')
bot_dataframe = check_bot_dataframe_copy.loc[check_bot_dataframe_copy['bot_score'] > 0.4]

# %%
bot_dataframe.shape
# Out:
# (396, 2)

# %%
botometer_bot_ids = list(bot_dataframe['account'])
# botometer_bot_ids

# %%
tweet_2016_2017_combined = pd.concat([tweet_2016_without_bot, tweet_2017_without_bot], axis=0)
tweet_2016_2017_combined.shape
# Out:
# (258330, 47)

# %%
tweet_2016_2017_final_filtered = tweet_2016_2017_combined.loc[~tweet_2016_2017_combined['user_id_str'].isin(botometer_bot_ids)]

# %%
tweet_2016_2017_final_filtered.shape
# Out:
# (250082, 47)

# %%
tweet_2016_2017_final_filtered.to_csv(os.path.join(bot_check_path, 'tweet_2016_2017_final_filtered.csv'), encoding='utf-8', 
                                     quoting=csv.QUOTE_NONNUMERIC)

# %%
tweet_2016_2017_final_filtered[['text', 'user_id_str']]
# Out:
#                                                   text         user_id_str
# 12   #Working #Saturday #Afternoon! #Final #Touch i...            46583766
# 19   I'm at Hong Kong International Airport <U+9999...            60469721
# 32   Preparing for a photo shoot #glamourshots #bla...           854043475
# 37   I'm at Thai Basil in Admiralty https://t.co/LZ...           240570319
# 43   For #mothers or #kids ' #mother <U+263A><U+263...            76045582
# 45   <U+652F><U+6301><U+5C0F><U+5E97> (@ <U+661F><U...              805174
# 47   If you're a #Engineering professional in #Tsim...            51949191
# 51   yeah. LA DISNEY. lol @ <U+9999><U+6E2F><U+8FEA...          1901024592
# 49   Cheap hair cut (@ Scissor House) https://t.co/...              805174
# 58   Just posted a photo @ Mongkok- <U+65FA><U+89D2...           121710473
# 63   Captain and Team Manager awaiting the bus for ...           346491708
# 64   Woman who defied 300 neo-Nazis at Swedish rall...           882077492
# 67   <ed><U+00A0><U+00BC><ed><U+00BF><U+00B3><ed><U...           334034890
# 75   @PhilipsShiu <U+5982><U+4F55><U+91DD><U+5C0D><...          3066946447
# 86   <U+4E0B><U+5348><U+8336><U+7DCA><U+63A5><U+4F4...            62536337
# 87   Just posted a video @ Yaumatei Kowloon Hongkon...           121710473
# 108  Global sleeping patterns revealed by app data ...           882077492
# 147  Join the Manulife team! See our latest #IT #jo...            51949191
# 156  <U+526A><U+500B><U+9AEA>,<U+914D><U+500B><U+65...           384942125
# 162  #hongkong #sky100 #victoriaharbour @ Sky100 - ...            33618355
# 167  <U+7747><U+597D><U+6232>:<U+5317><U+4EAC><U+90...           191738379
# 170  Dry aged prime rib roasts. A great tour of the...            58548253
# 180  Mommys little helper. Helping me fix my shoes ...            39198645
# 181  Sending flowers back home. She will love it #m...          2892410942
# 184  Having fun and joy #hoteliconhk @ Above &amp; ...           233875229
# 188  Exploring The Magical World of HK Disneyland. ...           133382579
# 193  Beautiful day! But so damn hot!!\r\r\n\r\r\n#H...            16251766
# 201  <ed><U+00A0><U+00BC><ed><U+00BD><U+0080> #Grac...           501455889
# 204  <ed><U+00A0><U+00BD><ed><U+00B8><U+008E><U+261...            29213391
# 223  I hope this guy loves his job. Walking to work...          1907635285
# ..                                                 ...                 ...
# 229  Ending 2017 with an airport photo in the hope ...           125271091
# 233  #åæ¸ @ Sun Yat Sen Memorial Park https://t....           461407738
# 238  Thank you 2017, Happy new year everyone í ¼í¾...          1170114775
# 239  New year eve party @ Hong Kong https://t.co/cK...           439671436
# 243  Landmark#landmarkhk#central#hongkong#trip#holi...           350245890
# 252  3/7 of the fireworks squad @ Hong Kong https:/...           576692578
# 261  .\r\nI want nobody nobody but youâ¦ https://t...           947757529
# 262  ååç¼ä½äº 1 å¼µç¸ç @ Sun Yat Sen Memo...           461407738
# 264  Out with the old, In with the new. Happy Nee Y...          3315689107
# 271  Counting down to 2018\r\n#countdown2018 #ziniz...           104213869
# 292  It was a great year, we enjoyed it a lot. We w...            46072362
# 296  Today is the last day of 2017, and my parents ...          2695770878
# 307  My year end jogging even after business trip f...           439671436
# 309  Bye sis í ½í± jessiemoksw\r\nAll the best in ...          1959309325
# 314  2017.12.31\r\n2017æå¾ä¸æåç¾æ¯å¥½éí...           392282054
# 317  ååç¼ä½äº 1 å¼µç¸ç @ Sun Yat Sen Memo...           461407738
# 357  Happy new year everyone âºï¸âºï¸ @ Hong Ko...  884683022015934464
# 360  [#HappyHolidays] #AppleStore of #ifc is so cro...            53541705
# 362  2017å¹´çå¹´æ«éæ¯ä¾äºè®é¦æ¨åæ©è¶...           157482892
# 375  í ¼í¼Hong Kong - Unlimited Cityí ¼í¿ As we p...            30894915
# 390  The original crew :) @ ç³éç
# è https://t....            69466109
# 403  2017 byebye åå°±ä¸å¹´\r\nä»¥çºä»å¹´åä¹...            58658630
# 423  New Years Eve Celebrations @kerryhotelhk @HKDo...            21489561
# 447  ä¼è¡ç­åæ¸í ½í¸» @ Lan Kwai Fong HK è­æ¡...          2207496336
# 448  ååç¼ä½äº 1 å¼µç¸ç @ Lan Kwai Fong HK...          2207496336
# 486  2018 countdown!!!! Excited to welcome 2018 í ½...           130408039
# 498  2017åé»æ­¢åå°bestmoment\r\n2018æå¾
# æ¯...           496485046
# 499  é ç¥å¤§å®¶2018å¹´è¬äºé å©! \r\næ¯åäºº...            15732263
# 525  Met the love of my life in 2017, lest did I kn...            72469239
# 529  ç¥å¤§å®¶2018å¹´ãèº«ä½å¥åº·ï¼äºäºé å¿...  748845089632366594
#
# [250082 rows x 2 columns]

# %% [markdown]
# However, we notice that there are still some bots out there. For instance:

# %%
ads = tweet_2016_2017_final_filtered.loc[tweet_2016_2017_final_filtered['user_id_str'] == '51949191']

# %%
ads
# Out:
#               country country_code                      created_at  \
# 47   <U+9999><U+6E2F>           HK  Sat May 07 07:09:11 +0000 2016
# 147  <U+9999><U+6E2F>           HK  Sat May 07 07:23:07 +0000 2016
# 47   <U+9999><U+6E2F>           HK  Sun May 08 01:20:21 +0000 2016
# 126  <U+9999><U+6E2F>           HK  Sun May 08 01:48:26 +0000 2016
# 55   <U+9999><U+6E2F>           HK  Sun May 08 02:16:25 +0000 2016
# 94   <U+9999><U+6E2F>           HK  Sun May 08 02:30:24 +0000 2016
# 158  <U+9999><U+6E2F>           HK  Sun May 08 02:44:19 +0000 2016
# 235  <U+9999><U+6E2F>           HK  Sun May 08 02:58:15 +0000 2016
# 35   <U+9999><U+6E2F>           HK  Sun May 08 03:12:10 +0000 2016
# 100  <U+9999><U+6E2F>           HK  Sun May 08 03:26:05 +0000 2016
# 80   <U+9999><U+6E2F>           HK  Sun May 08 04:27:32 +0000 2016
# 130  <U+9999><U+6E2F>           HK  Sun May 08 04:41:47 +0000 2016
# 202  <U+9999><U+6E2F>           HK  Sun May 08 04:56:00 +0000 2016
# 101  <U+9999><U+6E2F>           HK  Sun May 08 05:24:32 +0000 2016
# 170  <U+9999><U+6E2F>           HK  Sun May 08 05:38:48 +0000 2016
# 90   <U+9999><U+6E2F>           HK  Sun May 08 06:21:37 +0000 2016
# 154  <U+9999><U+6E2F>           HK  Sun May 08 06:35:53 +0000 2016
# 218  <U+9999><U+6E2F>           HK  Sun May 08 06:50:12 +0000 2016
# 10   <U+9999><U+6E2F>           HK  Sun May 08 07:04:27 +0000 2016
# 86   <U+9999><U+6E2F>           HK  Sun May 08 07:18:45 +0000 2016
# 165  <U+9999><U+6E2F>           HK  Sun May 08 07:33:01 +0000 2016
# 221  <U+9999><U+6E2F>           HK  Sun May 08 07:47:17 +0000 2016
# 276  <U+9999><U+6E2F>           HK  Sun May 08 08:58:14 +0000 2016
# 188  <U+9999><U+6E2F>           HK  Sun May 08 09:40:35 +0000 2016
# 274  <U+9999><U+6E2F>           HK  Sun May 08 09:54:45 +0000 2016
# 58   <U+9999><U+6E2F>           HK  Mon May 09 00:24:13 +0000 2016
# 90   <U+9999><U+6E2F>           HK  Mon May 09 00:38:16 +0000 2016
# 132  <U+9999><U+6E2F>           HK  Mon May 09 00:52:16 +0000 2016
# 54   <U+9999><U+6E2F>           HK  Mon May 09 01:20:12 +0000 2016
# 0    <U+9999><U+6E2F>           HK  Mon May 09 02:02:14 +0000 2016
# ..                ...          ...                             ...
# 189         Hong Kong           HK  Thu Dec 29 09:45:37 +0000 2016
# 40          Hong Kong           HK  Fri Dec 30 00:37:59 +0000 2016
# 80          Hong Kong           HK  Fri Dec 30 01:40:48 +0000 2016
# 239         Hong Kong           HK  Fri Dec 30 03:09:46 +0000 2016
# 232         Hong Kong           HK  Fri Dec 30 04:13:21 +0000 2016
# 49          Hong Kong           HK  Fri Dec 30 05:37:34 +0000 2016
# 328         Hong Kong           HK  Fri Dec 30 07:22:52 +0000 2016
# 216         Hong Kong           HK  Fri Dec 30 08:04:57 +0000 2016
# 343         Hong Kong           HK  Fri Dec 30 08:26:00 +0000 2016
# 264         Hong Kong           HK  Fri Dec 30 09:08:07 +0000 2016
# 182         Hong Kong           HK  Fri Dec 30 09:55:24 +0000 2016
# 57          Hong Kong           HK  Fri Dec 30 23:56:07 +0000 2016
# 71          Hong Kong           HK  Sat Dec 31 02:48:41 +0000 2016
# 178         Hong Kong           HK  Sat Dec 31 03:09:23 +0000 2016
# 11          Hong Kong           HK  Sat Dec 31 03:30:03 +0000 2016
# 195         Hong Kong           HK  Sat Dec 31 04:11:26 +0000 2016
# 33          Hong Kong           HK  Sat Dec 31 04:32:12 +0000 2016
# 142         Hong Kong           HK  Sat Dec 31 04:52:50 +0000 2016
# 301         Hong Kong           HK  Sat Dec 31 05:13:30 +0000 2016
# 21          Hong Kong           HK  Sat Dec 31 05:34:14 +0000 2016
# 141         Hong Kong           HK  Sat Dec 31 05:54:53 +0000 2016
# 251         Hong Kong           HK  Sat Dec 31 06:15:32 +0000 2016
# 35          Hong Kong           HK  Sat Dec 31 06:36:10 +0000 2016
# 176         Hong Kong           HK  Sat Dec 31 07:01:52 +0000 2016
# 328         Hong Kong           HK  Sat Dec 31 07:23:14 +0000 2016
# 366         Hong Kong           HK  Sat Dec 31 08:27:29 +0000 2016
# 119         Hong Kong           HK  Sat Dec 31 08:48:52 +0000 2016
# 262         Hong Kong           HK  Sat Dec 31 09:10:15 +0000 2016
# 17          Hong Kong           HK  Sat Dec 31 09:31:42 +0000 2016
# 170         Hong Kong           HK  Sat Dec 31 09:53:11 +0000 2016
#
#                                            description           expanded_url  \
# 47   Follow this account for geo-targeted Other job...  http://bit.ly/1TqL7EO
# 147  Follow this account for geo-targeted Other job...  http://bit.ly/1pxYnLo
# 47   Follow this account for geo-targeted Other job...  http://bit.ly/1SAs5uG
# 126  Follow this account for geo-targeted Other job...  http://bit.ly/20ow7Yf
# 55   Follow this account for geo-targeted Other job...  http://bit.ly/1RMcngj
# 94   Follow this account for geo-targeted Other job...  http://bit.ly/1TTO94w
# 158  Follow this account for geo-targeted Other job...  http://bit.ly/1QSFUQ9
# 235  Follow this account for geo-targeted Other job...  http://bit.ly/1YIa1yO
# 35   Follow this account for geo-targeted Other job...  http://bit.ly/1TYHeWT
# 100  Follow this account for geo-targeted Other job...  http://bit.ly/20M2ccs
# 80   Follow this account for geo-targeted Other job...  http://bit.ly/1PsDQzV
# 130  Follow this account for geo-targeted Other job...  http://bit.ly/1Sp6lkV
# 202  Follow this account for geo-targeted Other job...  http://bit.ly/1RrCXq7
# 101  Follow this account for geo-targeted Other job...  http://bit.ly/1i7m0pM
# 170  Follow this account for geo-targeted Other job...  http://bit.ly/24g2U4I
# 90   Follow this account for geo-targeted Other job...  http://bit.ly/1QUK8XA
# 154  Follow this account for geo-targeted Other job...  http://bit.ly/1QbO8F1
# 218  Follow this account for geo-targeted Other job...  http://bit.ly/1SehxwV
# 10   Follow this account for geo-targeted Other job...  http://bit.ly/1ZhQWny
# 86   Follow this account for geo-targeted Other job...  http://bit.ly/1Srveso
# 165  Follow this account for geo-targeted Other job...  http://bit.ly/1M5SIUN
# 221  Follow this account for geo-targeted Other job...  http://bit.ly/1TJwhbB
# 276  Follow this account for geo-targeted Other job...  http://bit.ly/25esSWN
# 188  Follow this account for geo-targeted Other job...  http://bit.ly/1mU8GY3
# 274  Follow this account for geo-targeted Other job...  http://bit.ly/1U0Px4v
# 58   Follow this account for geo-targeted Other job...  http://bit.ly/1Nhu3cL
# 90   Follow this account for geo-targeted Other job...  http://bit.ly/1TWVCPp
# 132  Follow this account for geo-targeted Other job...  http://bit.ly/20Jvfxu
# 54   Follow this account for geo-targeted Other job...  http://bit.ly/1mUrlTy
# 0    Follow this account for geo-targeted Other job...  http://bit.ly/1St4tUE
# ..                                                 ...                    ...
# 189  Follow this account for geo-targeted Other job...  http://bit.ly/2hscjlV
# 40   Follow this account for geo-targeted Other job...  http://bit.ly/2ij4WyY
# 80   Follow this account for geo-targeted Other job...  http://bit.ly/2ijnqPH
# 239  Follow this account for geo-targeted Other job...  http://bit.ly/2fkWHnd
# 232  Follow this account for geo-targeted Other job...  http://bit.ly/2ijtCqX
# 49   Follow this account for geo-targeted Other job...  http://bit.ly/2h8unAP
# 328  Follow this account for geo-targeted Other job...  http://bit.ly/2haNABP
# 216  Follow this account for geo-targeted Other job...  http://bit.ly/2b6VD1c
# 343  Follow this account for geo-targeted Other job...  http://bit.ly/2hw3xmI
# 264  Follow this account for geo-targeted Other job...  http://bit.ly/2hwcQDv
# 182  Follow this account for geo-targeted Other job...  http://bit.ly/2gpLcHI
# 57   Follow this account for geo-targeted Other job...  http://bit.ly/2igVb6b
# 71   Follow this account for geo-targeted Other job...  http://bit.ly/2ihodmc
# 178  Follow this account for geo-targeted Other job...  http://bit.ly/2h8qnE9
# 11   Follow this account for geo-targeted Other job...  http://bit.ly/2hwuwyu
# 195  Follow this account for geo-targeted Other job...  http://bit.ly/2h99ZQq
# 33   Follow this account for geo-targeted Other job...  http://bit.ly/2gyvAoG
# 142  Follow this account for geo-targeted Other job...  http://bit.ly/2hwDKek
# 301  Follow this account for geo-targeted Other job...  http://bit.ly/2h8JSMK
# 21   Follow this account for geo-targeted Other job...  http://bit.ly/29CG5lx
# 141  Follow this account for geo-targeted Other job...  http://bit.ly/2hyADT4
# 251  Follow this account for geo-targeted Other job...  http://bit.ly/2hyK4SF
# 35   Follow this account for geo-targeted Other job...  http://bit.ly/2auat3H
# 176  Follow this account for geo-targeted Other job...  http://bit.ly/2bIT9oX
# 328  Follow this account for geo-targeted Other job...  http://bit.ly/2hbfxgD
# 366  Follow this account for geo-targeted Other job...  http://bit.ly/2bLCeX7
# 119  Follow this account for geo-targeted Other job...  http://bit.ly/2b3Qyqs
# 262  Follow this account for geo-targeted Other job...  http://bit.ly/2bD0BWZ
# 17   Follow this account for geo-targeted Other job...  http://bit.ly/2c9Rda6
# 170  Follow this account for geo-targeted Other job...  http://bit.ly/2dEEQog
#
#     favorited favourites_count followers_count friends_count  \
# 47      FALSE                0             638           495
# 147     FALSE                0             637           495
# 47      FALSE                0             631           495
# 126     FALSE                0             631           495
# 55      FALSE                0             631           495
# 94      FALSE                0             631           495
# 158     FALSE                0             630           495
# 235     FALSE                0             630           495
# 35      FALSE                0             630           495
# 100     FALSE                0             630           495
# 80      FALSE                0             630           495
# 130     FALSE                0             630           495
# 202     FALSE                0             629           495
# 101     FALSE                0             629           495
# 170     FALSE                0             630           495
# 90      FALSE                0             630           495
# 154     FALSE                0             630           495
# 218     FALSE                0             630           495
# 10      FALSE                0             633           495
# 86      FALSE                0             635           495
# 165     FALSE                0             635           495
# 221     FALSE                0             635           495
# 276     FALSE                0             635           495
# 188     FALSE                0             634           495
# 274     FALSE                0             634           495
# 58      FALSE                0             633           495
# 90      FALSE                0             634           495
# 132     FALSE                0             634           495
# 54      FALSE                0             633           495
# 0       FALSE                0             633           495
# ..        ...              ...             ...           ...
# 189     FALSE                0             687           495
# 40      FALSE                0             687           495
# 80      FALSE                0             688           495
# 239     FALSE                0             687           495
# 232     FALSE                0             687           495
# 49      FALSE                0             687           495
# 328     FALSE                0             688           495
# 216     FALSE                0             688           495
# 343     FALSE                0             688           495
# 264     FALSE                0             688           495
# 182     FALSE                0             688           495
# 57      FALSE                0             688           495
# 71      FALSE                0             687           495
# 178     FALSE                0             687           495
# 11      FALSE                0             687           495
# 195     FALSE                0             687           495
# 33      FALSE                0             687           495
# 142     FALSE                0             687           495
# 301     FALSE                0             687           495
# 21      FALSE                0             687           495
# 141     FALSE                0             687           495
# 251     FALSE                0             687           495
# 35      FALSE                0             687           495
# 176     FALSE                0             687           495
# 328     FALSE                0             687           495
# 366     FALSE                0             688           495
# 119     FALSE                0             689           495
# 262     FALSE                0             689           495
# 17      FALSE                0             689           495
# 170     FALSE                0             689           495
#
#                              full_name         ...         user_id_str  \
# 47   Yau Tsim Mong District, Hong Kong         ...            51949191
# 147   Kowloon City District, Hong Kong         ...            51949191
# 47    Kowloon City District, Hong Kong         ...            51949191
# 126   Kowloon City District, Hong Kong         ...            51949191
# 55    Kowloon City District, Hong Kong         ...            51949191
# 94       Tsuen Wan District, Hong Kong         ...            51949191
# 158       Wan Chai District, Hong Kong         ...            51949191
# 235        Eastern District, Hong Kong         ...            51949191
# 35       Tsuen Wan District, Hong Kong         ...            51949191
# 100       Wan Chai District, Hong Kong         ...            51949191
# 80        Wan Chai District, Hong Kong         ...            51949191
# 130   Kowloon City District, Hong Kong         ...            51949191
# 202   Kowloon City District, Hong Kong         ...            51949191
# 101   Kowloon City District, Hong Kong         ...            51949191
# 170   Kowloon City District, Hong Kong         ...            51949191
# 90    Kowloon City District, Hong Kong         ...            51949191
# 154   Kowloon City District, Hong Kong         ...            51949191
# 218   Kowloon City District, Hong Kong         ...            51949191
# 10        Wan Chai District, Hong Kong         ...            51949191
# 86    Kowloon City District, Hong Kong         ...            51949191
# 165   Kowloon City District, Hong Kong         ...            51949191
# 221   Kowloon City District, Hong Kong         ...            51949191
# 276  Yau Tsim Mong District, Hong Kong         ...            51949191
# 188        Eastern District, Hong Kong         ...            51949191
# 274   Kowloon City District, Hong Kong         ...            51949191
# 58    Kowloon City District, Hong Kong         ...            51949191
# 90       Tsuen Wan District, Hong Kong         ...            51949191
# 132       Wan Chai District, Hong Kong         ...            51949191
# 54       Tsuen Wan District, Hong Kong         ...            51949191
# 0     Kowloon City District, Hong Kong         ...            51949191
# ..                                 ...         ...                 ...
# 189       Wan Chai District, Hong Kong         ...            51949191
# 40        Wan Chai District, Hong Kong         ...            51949191
# 80        Wan Chai District, Hong Kong         ...            51949191
# 239       Wan Chai District, Hong Kong         ...            51949191
# 232       Wan Chai District, Hong Kong         ...            51949191
# 49        Wan Chai District, Hong Kong         ...            51949191
# 328       Wan Chai District, Hong Kong         ...            51949191
# 216       Wan Chai District, Hong Kong         ...            51949191
# 343       Wan Chai District, Hong Kong         ...            51949191
# 264       Wan Chai District, Hong Kong         ...            51949191
# 182     Kwai Tsing District, Hong Kong         ...            51949191
# 57        Wan Chai District, Hong Kong         ...            51949191
# 71        Wan Chai District, Hong Kong         ...            51949191
# 178       Wan Chai District, Hong Kong         ...            51949191
# 11        Wan Chai District, Hong Kong         ...            51949191
# 195        Eastern District, Hong Kong         ...            51949191
# 33        Wan Chai District, Hong Kong         ...            51949191
# 142       Wan Chai District, Hong Kong         ...            51949191
# 301       Wan Chai District, Hong Kong         ...            51949191
# 21        Wan Chai District, Hong Kong         ...            51949191
# 141       Wan Chai District, Hong Kong         ...            51949191
# 251       Wan Chai District, Hong Kong         ...            51949191
# 35        Wan Chai District, Hong Kong         ...            51949191
# 176       Wan Chai District, Hong Kong         ...            51949191
# 328       Wan Chai District, Hong Kong         ...            51949191
# 366       Wan Chai District, Hong Kong         ...            51949191
# 119       Wan Chai District, Hong Kong         ...            51949191
# 262       Wan Chai District, Hong Kong         ...            51949191
# 17        Wan Chai District, Hong Kong         ...            51949191
# 170       Wan Chai District, Hong Kong         ...            51949191
#
#     user_lang                             user_url utc_offset verified  \
# 47         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 147        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 47         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 126        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 55         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 94         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 158        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 235        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 35         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 100        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 80         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 130        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 202        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 101        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 170        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 90         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 154        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 218        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 10         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 86         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 165        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 221        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 276        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 188        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 274        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 58         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 90         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 132        en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 54         en  http://www.careerarc.com/job-seeker     -14400    FALSE
# 0          en  http://www.careerarc.com/job-seeker     -14400    FALSE
# ..        ...                                  ...        ...      ...
# 189        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 40         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 80         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 239        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 232        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 49         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 328        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 216        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 343        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 264        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 182        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 57         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 71         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 178        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 11         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 195        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 33         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 142        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 301        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 21         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 141        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 251        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 35         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 176        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 328        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 366        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 119        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 262        en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 17         en  http://www.careerarc.com/job-seeker     -18000    FALSE
# 170        en  http://www.careerarc.com/job-seeker     -18000    FALSE
#
#                        hk_time  year month month_plus_year            SmallTPU
# 47   2016-05-07 15:09:11+08:00  2016     5          2016_5                 212
# 147  2016-05-07 15:23:07+08:00  2016     5          2016_5                 234
# 47   2016-05-08 09:20:21+08:00  2016     5          2016_5                 234
# 126  2016-05-08 09:48:26+08:00  2016     5          2016_5                 234
# 55   2016-05-08 10:16:25+08:00  2016     5          2016_5                 234
# 94   2016-05-08 10:30:24+08:00  2016     5          2016_5  331-334, 336 & 340
# 158  2016-05-08 10:44:19+08:00  2016     5          2016_5                 133
# 235  2016-05-08 10:58:15+08:00  2016     5          2016_5                 151
# 35   2016-05-08 11:12:10+08:00  2016     5          2016_5  331-334, 336 & 340
# 100  2016-05-08 11:26:05+08:00  2016     5          2016_5                 133
# 80   2016-05-08 12:27:32+08:00  2016     5          2016_5                 133
# 130  2016-05-08 12:41:47+08:00  2016     5          2016_5                 234
# 202  2016-05-08 12:56:00+08:00  2016     5          2016_5                 234
# 101  2016-05-08 13:24:32+08:00  2016     5          2016_5                 234
# 170  2016-05-08 13:38:48+08:00  2016     5          2016_5                 234
# 90   2016-05-08 14:21:37+08:00  2016     5          2016_5                 234
# 154  2016-05-08 14:35:53+08:00  2016     5          2016_5                 234
# 218  2016-05-08 14:50:12+08:00  2016     5          2016_5                 234
# 10   2016-05-08 15:04:27+08:00  2016     5          2016_5                 133
# 86   2016-05-08 15:18:45+08:00  2016     5          2016_5                 234
# 165  2016-05-08 15:33:01+08:00  2016     5          2016_5                 234
# 221  2016-05-08 15:47:17+08:00  2016     5          2016_5                 234
# 276  2016-05-08 16:58:14+08:00  2016     5          2016_5                 214
# 188  2016-05-08 17:40:35+08:00  2016     5          2016_5                 151
# 274  2016-05-08 17:54:45+08:00  2016     5          2016_5                 234
# 58   2016-05-09 08:24:13+08:00  2016     5          2016_5                 234
# 90   2016-05-09 08:38:16+08:00  2016     5          2016_5  331-334, 336 & 340
# 132  2016-05-09 08:52:16+08:00  2016     5          2016_5                 133
# 54   2016-05-09 09:20:12+08:00  2016     5          2016_5  331-334, 336 & 340
# 0    2016-05-09 10:02:14+08:00  2016     5          2016_5                 234
# ..                         ...   ...   ...             ...                 ...
# 189  2016-12-29 17:45:37+08:00  2016    12         2016_12                 133
# 40   2016-12-30 08:37:59+08:00  2016    12         2016_12                 133
# 80   2016-12-30 09:40:48+08:00  2016    12         2016_12                 133
# 239  2016-12-30 11:09:46+08:00  2016    12         2016_12                 133
# 232  2016-12-30 12:13:21+08:00  2016    12         2016_12                 133
# 49   2016-12-30 13:37:34+08:00  2016    12         2016_12                 133
# 328  2016-12-30 15:22:52+08:00  2016    12         2016_12                 133
# 216  2016-12-30 16:04:57+08:00  2016    12         2016_12                 133
# 343  2016-12-30 16:26:00+08:00  2016    12         2016_12                 133
# 264  2016-12-30 17:08:07+08:00  2016    12         2016_12                 133
# 182  2016-12-30 17:55:24+08:00  2016    12         2016_12                 325
# 57   2016-12-31 07:56:07+08:00  2016    12         2016_12                 133
# 71   2016-12-31 10:48:41+08:00  2016    12         2016_12                 133
# 178  2016-12-31 11:09:23+08:00  2016    12         2016_12                 133
# 11   2016-12-31 11:30:03+08:00  2016    12         2016_12                 133
# 195  2016-12-31 12:11:26+08:00  2016    12         2016_12                 153
# 33   2016-12-31 12:32:12+08:00  2016    12         2016_12                 133
# 142  2016-12-31 12:52:50+08:00  2016    12         2016_12                 133
# 301  2016-12-31 13:13:30+08:00  2016    12         2016_12                 133
# 21   2016-12-31 13:34:14+08:00  2016    12         2016_12                 133
# 141  2016-12-31 13:54:53+08:00  2016    12         2016_12                 133
# 251  2016-12-31 14:15:32+08:00  2016    12         2016_12                 133
# 35   2016-12-31 14:36:10+08:00  2016    12         2016_12                 133
# 176  2016-12-31 15:01:52+08:00  2016    12         2016_12                 133
# 328  2016-12-31 15:23:14+08:00  2016    12         2016_12                 133
# 366  2016-12-31 16:27:29+08:00  2016    12         2016_12                 133
# 119  2016-12-31 16:48:52+08:00  2016    12         2016_12                 133
# 262  2016-12-31 17:10:15+08:00  2016    12         2016_12                 133
# 17   2016-12-31 17:31:42+08:00  2016    12         2016_12                 133
# 170  2016-12-31 17:53:11+08:00  2016    12         2016_12                 133
#
# [3525 rows x 47 columns]

# %% [markdown]
# We then set the prop_threshold = 0.6 and filter the dataframe again

# %%
final_dataframe = delete_bots_have_same_geoinformation(tweet_2016_2017_final_filtered, prop_threshold=0.6)
# Out:
# Done!

# %%
number_of_tweet_user(final_dataframe)
# Out:
# Total number of tweet is: 241123; Total number of user is 12109

# %%
final_dataframe.to_csv(os.path.join(bot_check_path, 'tweet_2016_2017_final_filtered.csv'), encoding='utf-8', 
                      quoting=csv.QUOTE_NONNUMERIC)

# %%
list(final_dataframe['text'])
# Out:
# ['#Working #Saturday #Afternoon! #Final #Touch is on the #way! #Excited! #JerryMaguire #Dessert?https://t.co/q4GWk8nZFm',
#  'Preparing for a photo shoot #glamourshots #blackandwhitephotohraphy #blackandwhite #beauty?https://t.co/PEVkAoleNQ',
#  "I'm at Thai Basil in Admiralty https://t.co/LZOfrTCq5W",
#  "For #mothers or #kids ' #mother <U+263A><U+263A><U+263A> \r\r\n#mothersday #<U+6BCD><U+89AA><U+7BC0> #<U+30D9><U+30A2><U+30D6><U+30EA><U+30C3><U+30AF> #<U+30D9><U+30A2><U+90E8> #<U+BCA0><U+C5B4><U+BE0C><U+B9AD> #medicomtoy #medicom?https://t.co/TCRjDS0b7c",
#  '<U+652F><U+6301><U+5C0F><U+5E97> (@ <U+661F><U+532F><U+6252><U+5C4B>) https://t.co/SmvbXpWz1Z https://t.co/R5RQZFSW5H',
#  'yeah. LA DISNEY. lol @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/ZAzarwc5f6',
#  'Cheap hair cut (@ Scissor House) https://t.co/XzzUajbs5C',
#  'Just posted a photo @ Mongkok- <U+65FA><U+89D2>, Hongkong https://t.co/bokpUZJU4R',
#  'Captain and Team Manager awaiting the bus for first game of tour vs?https://t.co/XDN5JHgpUm',
#  'Woman who defied 300 neo-Nazis at Swedish rally speaks of anger | World news | The Guardian https://t.co/RuWqlKolpk',
#  '<ed><U+00A0><U+00BC><ed><U+00BF><U+00B3><ed><U+00A0><U+00BC><ed><U+00BF><U+00B4><ed><U+00A0><U+00BC><ed><U+00BF><U+00B3><ed><U+00A0><U+00BC><ed><U+00BF><U+00B4> (at Artisan Room) [pic] ?https://t.co/CJFlasVxtp',
#  '@PhilipsShiu <U+5982><U+4F55><U+91DD><U+5C0D><U+FF1F>',
#  '<U+4E0B><U+5348><U+8336><U+7DCA><U+63A5><U+4F4F><U+5348><U+9910> (@ <U+91D1><U+8C6A><U+8336><U+9910><U+5EF3> in Kowloon City, Hong Kong, Kowloon) https://t.co/RrXWTfnHOG',
#  'Just posted a video @ Yaumatei Kowloon Hongkong https://t.co/jzc3uBYyOu',
#  'Global sleeping patterns revealed by app data - BBC News https://t.co/xU5SOmXiFb',
#  '<U+526A><U+500B><U+9AEA>,<U+914D><U+500B><U+65B0><U+592A><U+967D><U+773C><U+93E1>,<U+8FCE><U+63A5><U+4ECA><U+500B><U+590F><U+5929>\r\r\n\r\r\n#NativeSons #Sunglasses #mastercraft #Japan #Summer #Fuller?https://t.co/8TxS8JbId3',
#  "#hongkong #sky100 #victoriaharbour @ Sky100 - Hong Kong's Observation Deck https://t.co/tgQJOMwhJG",
#  '<U+7747><U+597D><U+6232>:<U+5317><U+4EAC><U+9047><U+4E0A><U+897F><U+96C5><U+5716><U+4E4B><U+4E0D><U+4E8C><U+60C5><U+66F8> @ Broadway The ONE <U+767E><U+8001><U+532F>The ONE<U+6232><U+9662> https://t.co/8LhuVGNcca',
#  "Dry aged prime rib roasts. A great tour of the Butcher's Club original private kitchen.  \r\r\n\r\r\nMeat?https://t.co/Uh2vIw6Vwm",
#  'Mommys little helper. Helping me fix my shoes <ed><U+00A0><U+00BD><ed><U+00B8><U+0098>#leahthewestie #leahlovesdaddy #westie #westigram?https://t.co/Ei20eROoBo',
#  'Sending flowers back home. She will love it #mothersday #mom #love #mama @ Hong Kong https://t.co/Hb8P18ReWp',
#  'Having fun and joy #hoteliconhk @ Above &amp; Beyond <U+5929><U+5916><U+5929> at Hotel ICON https://t.co/u4VDG4P1rD',
#  'Exploring The Magical World of HK Disneyland. <ed><U+00A0><U+00BD><ed><U+00B1><U+008C> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/HtRKX4QvLS',
#  'Beautiful day! But so damn hot!!\r\r\n\r\r\n#HarbourCity #TsimShaTsui #StreetPhotography #blackandwhite?https://t.co/ZgFvrJ6y1Z',
#  '<ed><U+00A0><U+00BC><ed><U+00BD><U+0080> #GraciasInfinitas #VivirLaVida #HK @ Hung Hom Station https://t.co/46RZ6fciCL',
#  '<ed><U+00A0><U+00BD><ed><U+00B8><U+008E><U+2615><U+FE0F> #coffee #lof10 #ootd #wiwt #hongkong #sohot #luksintranslation @ <U+8FA6><U+9928> Lof 10 https://t.co/3mza61bMsN',
#  'I hope this guy loves his job. Walking to work with your suit in hand, because the heat and?https://t.co/JEKzTU0tru',
#  'That\x92s obviously a horse (@ Kowloon City Plaza <U+4E5D><U+9F8D><U+57CE><U+5EE3><U+5834> in Kowloon City) https://t.co/53b4og5CgD https://t.co/n7RXPPWuI1',
#  "Hubby and I were telling the kids that we won't be buying food inside Disney because we just ate?https://t.co/onrOQQ9xo5",
#  'Just posted a photo @ Hong Kong https://t.co/6DQbXv7T44',
#  "I'm at McDonald's <U+9EA5><U+7576><U+52DE> in Mong Kok https://t.co/V0htZyVjlo",
#  'Nice view! @ <U+990A><U+548C><U+91AB><U+9662> Hong Kong Sanatorium &amp; Hospital https://t.co/jYv0UUV6gg',
#  'Family. <ed><U+00A0><U+00BD><ed><U+00B1><U+00AA> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/FJQuipyFB9',
#  "Because when you're at a men's conference you do manly things. #islandecchk?https://t.co/d3kMzluQdY",
#  '87 Reclamation street #ReclamationStreet #kowloon #HongKong #hk #China? #Earth #Nikon #D4?https://t.co/3RyLTH7u5c',
#  "Strawberry Vanilla Honey Toast\r\r\n\r\r\nYum! Didn't know there was a surprise inside those thick?https://t.co/SsBQMouKlS",
#  'Just posted a photo @ Jerry Maguire Cocktails &amp; Desserts https://t.co/e3sWISLW5G',
#  'Mango Fudge Honey Toast\r\r\n\r\r\nThis one is also delicous and has a more subtler taste than the?https://t.co/QjV1lQhzct',
#  'they asked me for a selfie. <ed><U+00A0><U+00BD><ed><U+00B8><U+0085> with the Chipmunks. <ed><U+00A0><U+00BD><ed><U+00B0><U+00BF> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/4TM7UqRJ6N',
#  '<U+6709><U+6642><U+5019>,<U+8449><U+6BD4><U+82B1><U+66F4><U+7F8E><U+3002> @ Kowloon Tsai Park https://t.co/p792RmhC34',
#  '<U+26F0>yamagirl go go \r\r\ncheck (it) out please<ed><U+00A0><U+00BC><ed><U+00BF><U+00A8>?https://t.co/XCHLBQ5aK2',
#  "Marcus Leung, 1 day old!!!   Welcome our newest member to Leung's!!!  I have a nephew again!!!!?https://t.co/sDU727o6FQ",
#  "As a person who was born during the year of the Rabbit, I didn't know that it would be foretold?https://t.co/lm6DyOdxQW",
#  'with Donald and Daisy. <ed><U+00A0><U+00BD><ed><U+00B1><U+008C> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/pfCUgIJ34M',
#  "I'm at Pacific Place <U+592A><U+53E4><U+5EE3><U+5834> in Admiralty, Central and Western District https://t.co/Afg1i3uZH5",
#  'It was amazing seeing a temple this magnificent <ed><U+00A0><U+00BD><ed><U+00B8><U+0081> #templehopping @ <U+5FD7><U+84EE><U+7D20><U+9F4B>@Nan Lian Garden https://t.co/OH0UfabaSU',
#  'And I made it <ed><U+00A0><U+00BD><ed><U+00B2><U+00AA><ed><U+00A0><U+00BC><ed><U+00BF><U+00BC> hiking to the peak on a sunny beautiful day in Hong Kong. Absolutely stunning <ed><U+00A0><U+00BD><ed><U+00B8><U+008D>?https://t.co/4bkagEWSeE',
#  '#kapok10 party from now until 8pm. DJ @kapoknews at the booth.  Music on his own terms. Yeh! :)?https://t.co/34TXRc6Ti4',
#  '160507 @ <U+576A><U+6D32><U+5357><U+7063> https://t.co/P3iHd6gnwA',
#  'Define "hot". <ed><U+00A0><U+00BD><ed><U+00B4><U+00A5> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/m3AcDGZrI5',
#  'ifc, Central District <U+4E2D><U+74B0>\r\r\n-&gt; Victoria Peak <U+7DAD><U+591A><U+5229><U+4E9E><U+5C71><U+9802>\r\r\n\r\r\n#Hongkong #central?https://t.co/w0ByvGvcGn',
#  '160507 <U+66EC><U+54B8><U+9B5A> @ <U+576A><U+6D32><U+5357><U+7063> https://t.co/ZHeSol8Kzb',
#  "I'm at TC2 Caf?&amp; Workshop in Mong Kok https://t.co/psEV2plUHR",
#  '<ed><U+00A0><U+00BD><ed><U+00B2><U+0090> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/VLeNlSCgvE',
#  'woke up still tired home alone (@ Fairview Mansion <U+83EF><U+723E><U+5927><U+5EC8> in Causeway Bay) https://t.co/ll916YmRyR',
#  "I'm at MTR Kowloon Tong Station in Kowloon Tong https://t.co/7eIf9Nh0Em",
#  'Brunch semi buffet with the main as Linguini with Shrimp in Spicy Tomato Sauce - the flavours?https://t.co/e8a9osuPkG',
#  '@kmwan go for flagship, it should be better than A9',
#  'Pompurin (at The ONE) [pic] ?https://t.co/QaoX3xd8xs',
#  'Big buildings in H-K <ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0><ed><U+00A0><U+00BD><ed><U+00B1><U+008C> @ Hong Kong https://t.co/xH4mvblpcl',
#  '<U+5C16><U+6C99><U+5480><U+958B><U+5DE6><U+4E2D><U+6751><U+85E4><U+5409><U+5187><U+4EBA><U+6392><U+3002><U+5EE2><U+9752><U+98DF><U+5514><U+8D77><U+3002><U+53C8>,<U+500B><U+4EBA><U+8A8D><U+70BA><U+4F0A><U+85E4><U+4E45><U+53F3><U+885B><U+9580><U+597D><U+98DF><U+5572> (@ <U+4E2D><U+6751><U+85E4><U+5409><U+9999><U+6E2F><U+5E97> (Nakamura Tokichi)) https://t.co/jXJEQxLJ7a https://t.co/BTUqJ70sD0',
#  'Eggs. <ed><U+00A0><U+00BD><ed><U+00B9><U+0083> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/Dhx0jVrmID',
#  '<U+8DB7><U+9AD8><U+5F71> <U+597D><U+8F9B><U+82E6> <U+4E0D><U+904E><U+898B><U+5230><U+90FD><U+503C><U+5F97>!#kimhanbin kimhanbi#b.i #ikon @ <U+65FA><U+89D2><U+6717><U+8C6A><U+574A>Mongkok Langham?https://t.co/AbJs45B6WX',
#  'Magically Magic <ed><U+00A0><U+00BD><ed><U+00B1><U+008C> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/63Tc7hy8xy',
#  'theater in the wild. <ed><U+00A0><U+00BC><ed><U+00BC><U+00B3> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/sxsEb9O9cP',
#  '<ed><U+00A0><U+00BD><ed><U+00B8><U+00B5><ed><U+00A0><U+00BD><ed><U+00B8><U+00B5><ed><U+00A0><U+00BD><ed><U+00B8><U+00B5> @ Causeway Bay https://t.co/B6pmp7LQ7z',
#  'Leisure ride my ass. Another killing hill training with gibborecoil bobbowles recoilbikes 50km?https://t.co/SLpyH48F4O',
#  'the lion king. <ed><U+00A0><U+00BE><ed><U+00B6><U+0081> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/zVTF0Gc1xq',
#  '07.05.2016 || When you have the opportunity, you S T R I K E <U+2714>\r\r\n\r\r\n#oddies #mangoicecream #dessert?https://t.co/1Nq60OsYlm',
#  'Tree house. <ed><U+00A0><U+00BC><ed><U+00BF><U+0095> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/WkU28JE73T',
#  '<U+9072><U+4F86><U+7684><U+5348><U+98EF>: <U+53C9><U+9AA8><U+98EF> (@ Wah Fung <U+83EF><U+8C50><U+71D2><U+81D8> in Central) https://t.co/UxwIHMSHdD https://t.co/XslLy4luKk',
#  '#Working #Saturday #Afternoon! #Final #Touch is on the #way! #Excited! #JerryMaguire?https://t.co/tJ2RB2je58',
#  "When you can't decide where to have lunch and you just ended up in the same restaurant <ed><U+00A0><U+00BD><ed><U+00B8><U+00AD> for the?https://t.co/TOVAk4EFRQ",
#  'National Anthems @ HONG KONG FOOTBALL CLUB https://t.co/m5I6QTiBMU',
#  'Enjoying the afternoon in Hong Kong and ignoring the fact we leave soon <ed><U+00A0><U+00BD><ed><U+00B8><U+0080> #discoverhongkong?https://t.co/TbpImQOplz',
#  'Randy talks Man Keung and his 11 years of music journey!!! #<U+9019><ed><U+00A1><U+0095><ed><U+00BA><U+0083><U+627E><U+5171><U+9CF4> mankeungchow laikm unununa?https://t.co/MyO6juqNC2',
#  '160507 <U+4E0B><U+5348><U+8336><U+9910> - <U+7D05><U+8C46><U+51B0><U+52A0><U+897F><U+591A> @ <U+91D1><U+6E90><U+51B0><U+5BA4> https://t.co/hX6bLYCb0M',
#  '#Working #Saturday #Afternoon! #Final #Touch is on the #way! #Excited! #JerryMaguire?https://t.co/QlzqrUmhSF',
#  "I'm at MTR Sha Tin Station <U+6C99><U+7530><U+7AD9> in Sha Tin https://t.co/mxCJaz5aGb",
#  'Thanks for years of waiting, now I make you mine. #summer #weekend?https://t.co/lAGx0vS5L7',
#  'Hong Kong vs Japan National Rugby Teams! My first live professional match! (@ Hong Kong Football Club <U+9999><U+6E2F><U+8DB3><U+7403><U+6703>) https://t.co/IEpFyfB5bu',
#  'Jenny Czech again! more at https://t.co/fBOcaQSgSA #boudoir #boudoirmodel #boudoirphotography?https://t.co/jDPodJvAt8',
#  '#soexcited<ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BD><ed><U+00B8><U+008D> @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/apTdGGztMc',
#  '<U+501F><U+5B34> (@ Tseung Kwan O Public Library <U+5C07><U+8ECD><U+6FB3><U+516C><U+5171><U+5716><U+66F8><U+9928> in Tseung Kwan O, Hong Kong) https://t.co/GOeMSWsoCL https://t.co/FUcixKjEZ9',
#  'Just posted a photo @ Terminal 1 Hongkong International Airport https://t.co/fyGa0Jgu8A',
#  '<U+5929><U+6674> #<U+5929><U+6674> #<U+5929><U+6674><U+308C> #<U+2600><U+FE0E> #central #hongkong @ HK ifc mall <U+9999><U+6E2F><U+570B><U+969B><U+91D1><U+878D><U+4E2D><U+5FC3><U+5546><U+5834> https://t.co/wFGw7rEEFt',
#  "I'm at MTR Tai Koo Station <U+592A><U+53E4><U+7AD9> in Taikoo Shing, Hong Kong https://t.co/IncoJZ6wDE",
#  "I'm at Hong Kong International Airport <U+9999><U+6E2F><U+570B><U+969B><U+6A5F><U+5834> (HKG) - @hkairport in Islands District, Hong Kong https://t.co/ZgYnqqthUw",
#  "I'm at IFC Mall <U+570B><U+969B><U+91D1><U+878D><U+4E2D><U+5FC3><U+5546><U+5834> - @hkifcmall in Hong Kong https://t.co/uKTatCV3RM",
#  'No need any filter <U+2600><U+FE0F><U+2600><U+FE0F><U+2600><U+FE0F><U+2600><U+FE0F>\r\r\n#spriteonthego #spriteXhongkong @ Gough Street https://t.co/HG73gjREzq',
#  '#pineapplebun #nofilter @ <U+91D1><U+83EF><U+51B0><U+5EF3> Kam Wah Cafe https://t.co/06rm6s3dAK',
#  '#feelinghot #notreadyforsummer #dontwannagettan #itsonlymaythough \r\r\nI miss the cold weather<ed><U+00A0><U+00BD><ed><U+00B9><U+0088><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD><ed><U+00A0><U+00BD><ed><U+00B8><U+00AD> @\x85 https://t.co/OeujSAylMU',
#  "I'm at Café Matchbox <U+559C><U+559C><U+51B0><U+5BA4> in Causeway Bay https://t.co/N4Qs0mx8dx https://t.co/IgB8r6oC9H",
#  '<U+662F><U+65E5><U+96FB><U+5F71>:<U+7F8E><U+570B><U+968A><U+9577>3:<U+82F1><U+96C4><U+5167><U+6230>\r\r\nCaptain America 3: Civil War \r\r\n(<U+60F3><U+77E5><U+597D><U+8010>,<U+7FA4><U+6BC6><U+6210><U+5481>,<U+9EDE><U+89E3><U+5514><U+7528><U+5FA9><U+4EC7><U+8005><U+505A><U+724C><U+982D><U+FF1F>) (@ UA Cityplaza UA<U+592A><U+53E4><U+57CE><U+4E2D><U+5FC3>) https://t.co/XuxzJ3sFc9',
#  'Can I take you home with meee? <ed><U+00A0><U+00BD><ed><U+00B8><U+008A> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/moiL3LAvB7',
#  'May is a crazy months so many I know are born in month May lol! #birthdayshots #shots #birthday\x85 https://t.co/OkWmjxBYX5',
#  "I'm at Joint Publishing <U+4E09><U+806F><U+66F8><U+5E97> in Central https://t.co/4SlMCwY8l9",
#  'I just began a cycling workout using #Endomondo. Peptalk me now @ https://t.co/XSEaCNDxZD',
#  "I'm very happy with my Godmother and Godfather this afternoon! I have been waiting for 20 years\x85 https://t.co/EG4Xyow9QP",
#  'Just take a photo, then breathe.. \r\r\nThis is LIFE. #traveller #discoverThings @ Mongkok Shoping\x85 https://t.co/MtopAubHmH',
#  '#HKSEDS <U+5C0E><U+76F2><U+72AC><U+5C0F>B @ PMQ <U+5143><U+5275><U+65B9> https://t.co/GuL16O6pAP',
#  'Heat of Summer Sunshine (at Star Ferry Pier (Tsim Sha Tsui) <U+5929><U+661F><U+6E21><U+8F2A><U+78BC><U+982D>(<U+5C16><U+6C99><U+5480>)) [pic] \x97 https://t.co/dKkzY3MBof',
#  '<U+7FBD><U+8863><U+7518><U+85CD><U+6C99><U+62C9>! @ The ONE https://t.co/8ZyM62x6cI',
#  '<U+521D><U+4E00><U+71D2><U+68C9><U+82B1><U+7CD6> @ Ann Choi Heritage Studio in Wanchai https://t.co/Yv51c7M3VH',
#  "Cos I've been missing lukeslobster_jp so much so we ordered #lobstersandwich <ed><U+00A0><U+00BE><ed><U+00B4><U+0094> @ <U+5496><U+5561><U+5F04><U+9285><U+947C><U+7063><U+5E97> https://t.co/h0HYiWJdHG",
#  '#lantauisland #ngongping #hongkong #polinmonastery @ Ngong Ping 360 Cable Car to The Big Buddha https://t.co/uAQtSReyn5',
#  '<ed><U+00A0><U+00BD><ed><U+00B1><U+008D><ed><U+00A0><U+00BC><ed><U+00BF><U+00BB><ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0><ed><U+00A0><U+00BC><ed><U+00BD><U+009F><ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0><ed><U+00A0><U+00BC><ed><U+00BD><U+009F><ed><U+00A0><U+00BD><ed><U+00B1><U+008D><ed><U+00A0><U+00BC><ed><U+00BF><U+00BB><U+301C><ed><U+00A0><U+00BD><ed><U+00B2><U+008B><ed><U+00A0><U+00BD><ed><U+00B2><U+008B> @ Okashi Galleria X Calbee Plus https://t.co/s0fV0TrnGu',
#  '<U+7747>con<U+6709><U+5F97><U+7747><U+57CB><U+7DB5><U+6392>..<U+597D><U+5E78><U+798F><ed><U+00A0><U+00BC><ed><U+00B6><U+0092>\r\r\n#soundcheckparty #ikon #ikonic @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/Jl1N5bUlbQ',
#  "I'm at Hong Kong Zoological and Botanical Gardens <U+9999><U+6E2F><U+52D5><U+690D><U+7269><U+516C><U+5712> in Central https://t.co/2WqdfsdRGN",
#  'Sai Kung for one day #hksizzle @ <U+897F><U+8CA2><U+516C><U+773E><U+78BC><U+982D> Sai Kung Public Pier https://t.co/i7mWm1Jpgw',
#  '<ed><U+00A0><U+00BD><ed><U+00BA><U+0090><ed><U+00A0><U+00BC><ed><U+00BD><U+0094><ed><U+00A0><U+00BC><ed><U+00BC><U+00AD><ed><U+00A0><U+00BC><ed><U+00BC><U+00AF><ed><U+00A0><U+00BC><ed><U+00BD><U+00AA> Hong Kong Food Truck Festival! Until tomorrow only. | I want something unusual, so I chose\x85 https://t.co/ebfkoeoyB2',
#  'Look at all this dukkah. Just kidding, it\'s "sand" at Repulse Bay. #beach #sand #hongkong @\x85 https://t.co/Jvef4LDM8U',
#  "Whose birthday and who's too tired to smile for the camera?\x85 https://t.co/tGYE7VF7E1",
#  'Sai kung for one day #hksizzle @ <U+897F><U+8CA2><U+516C><U+773E><U+78BC><U+982D> Sai Kung Public Pier https://t.co/xEuw9JhYbz',
#  "I'm still the prettiest one! #cherryandmuimuibirthday @ <U+897F><U+8CA2><U+516C><U+773E><U+78BC><U+982D> Sai\x85 https://t.co/WAYvAf1fQl",
#  '5.5k swim today. Lost googles 1/3 of way in. Tis but a scratch! (@ Repulse Bay Beach <U+6DFA><U+6C34><U+7063><U+6CF3><U+7058>) https://t.co/wC0jXgWieM https://t.co/DIKU55evdM',
#  'The view from Wolomaloo Prime Restaurant in Kowloon. In the BG you can see HK Island. @ The ONE https://t.co/2ivSWv1LII',
#  'Bye bye Tin Hau. See you in two weeks! <ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0>&gt;<ed><U+00A0><U+00BC><ed><U+00B7><U+00A6><ed><U+00A0><U+00BC><ed><U+00B7><U+00BA>\r\r\n#lettheadventurebegin #lifewelltravelled #travel\x85 https://t.co/rzwybBadxu',
#  '"My footsteps will eventually fade away. But the shadow of regret\x85 https://t.co/wV252q0IOl',
#  '<U+53EF><U+5E72><U+64FE><U+601D><U+60F3><U+7684><U+5480><U+5FAE><U+5FAE><U+5F35><U+958B>\x85\r\r\n#<U+82B1><U+751F><U+4ED4> #<U+71B1><U+8840><U+4E5D><U+9F8D><U+6771> #<U+7B11><U+6B7B><U+6715> @ <U+5EB7><U+5BE7><U+9053><U+8DB3><U+7403><U+5834> https://t.co/Od5EFOmeuo',
#  'Happy birthday Cherry and Mui Mui #cherryandmuimuibirthday @ <U+897F><U+8CA2><U+516C><U+773E><U+78BC><U+982D>\x85 https://t.co/04wJ9p26FG',
#  "I'm at Swiss Café <U+745E><U+58EB><U+5496><U+5561><U+5BA4> in Cheung Sha Wan https://t.co/r0KZRtzThN",
#  'Coffee time <U+2764><U+FE0F> #coffee #starbucks #waitingforIKON #IKONinHongKong2016 @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/zbOz8foGQW',
#  '<U+9EC3><U+91D1><U+6BD2><U+8CE4><U+86D9> (@ Golden Computer Arcade <U+9EC3><U+91D1><U+96FB><U+8166><U+5546><U+5834> in Sham Shui Po) https://t.co/KaeBx77XF2 https://t.co/2rROiQfKqb',
#  'hiking on Victoria Peak <U+7DAD><U+591A><U+5229><U+4E9E><U+5C71><U+9802><U+884C><U+5C71>\r\r\n\r\r\n#Hongkong #the peak #victoriapeak\x85 https://t.co/a0w886XlFX',
#  '<U+958B><U+82B1><U+4E86>,<U+521D><U+590F><U+4E86><U+3002> @ <U+897F><U+8CA2> Sai Kung https://t.co/hIXE2LyUhB',
#  'Who wants some cheese tart om nom nom nom<ed><U+00A0><U+00BD><ed><U+00B8><U+009D><ed><U+00A0><U+00BD><ed><U+00B8><U+008B><ed><U+00A0><U+00BD><ed><U+00B8><U+008B><ed><U+00A0><U+00BD><ed><U+00B8><U+008B> #cheesetart #fattening @ Hong Kong https://t.co/rReUgU84E7',
#  'Falls. <ed><U+00A0><U+00BD><ed><U+00B1><U+008C> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/UkuGmsg6P7',
#  'Delightful moment \r\r\n#joelrobuchon #crepe #icecream #sundae #coffee #afternoontea #relax #hkfoodie\x85 https://t.co/fQwu3utv6E',
#  "my first try of disneyworld's strawberry flavored popcorn, and it taste yum af #RenceOnHK\x85 https://t.co/glxo0bHbtE",
#  '#snoopysworld  #snoopysworldhk #snoopysworld<U+53F2><U+8AFE><U+6BD4><U+958B><U+5FC3><U+4E16><U+754C> #ighk #hkig #shatin #hongkong @ <U+53F2><U+8AFE><U+6BD4><U+958B><U+5FC3><U+4E16><U+754C>\x85 https://t.co/XsapZJqa9n',
#  'Happy kiddos @sqalcantara lerniquinones lerma_quinones @ Whampoa\x85 https://t.co/H3z9NfCtZS',
#  '#quote#genius#rich#street#selfie#style#studio#studiolife#recording#recordingstudio##art#artist#si\x85 https://t.co/TtCW8C0xDQ',
#  "#hk knows whose kickin' it! #ripphife #ripphifedawg #funkydiabetic #phifediggy atribecalledquest\x85 https://t.co/ICm2ui0vsK",
#  '#HYPR | Keep walking.\r\r\n\r\r\n#PMQ #stairs #mural #cantonese #opera #culture #painting #walk #unionjack\x85 https://t.co/Dn0m4PaFgX',
#  'Keys filed here #hk #hkig @ <U+5EDF><U+8857> Temple Street https://t.co/kH7xBlqh67',
#  'Creepy in Fa Yuen Gai #cats #hk #hongkong @ <U+65FA><U+89D2> - Mong Kok https://t.co/Iec9xRIAuk',
#  '<U+7DA0><U+8336><U+829D><U+58EB><U+86CB><U+7CD5><U+771F><U+4FC2><U+597D><U+597D><U+98DF>,<U+4F46><U+7531><U+65BC><U+50F9><U+9322><U+95DC><U+4FC2><U+5514><U+53EF><U+4EE5><U+6210><U+65E5><U+98DF> <ed><U+00A0><U+00BD><ed><U+00B8><U+009D> @ teakha <U+8336><U+3002><U+5BB6> https://t.co/cumlKLVh5p',
#  '<U+4F86><U+81EA><U+5370><U+5EA6><U+7684><U+5927><U+5E2B>? @ Star Ferry Pier, Tsim Sha Tsui <U+5C16><U+6C99><U+5480><U+5929><U+661F><U+78BC><U+982D> https://t.co/7ikWZU4B1v',
#  'View from the hotel #mumisawayonwork #HK #lovemylife @ Sheraton Hong Kong Hotel &amp; Towers (Official) https://t.co/xBzwHNI0rU',
#  'Need some time off here. To escape from the real estate agents here at @hkharbourcity. They are?https://t.co/7BeWxwfgsg',
#  'Happiness. <ed><U+00A0><U+00BC><ed><U+00BF><U+00B0> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/j8dCo9NxI9',
#  "Let's party tonight #ikonic koh_luzizi <ed><U+00A0><U+00BD><ed><U+00B9><U+008C><ed><U+00A0><U+00BC><ed><U+00BF><U+00BB><ed><U+00A0><U+00BD><ed><U+00B9><U+008C><ed><U+00A0><U+00BC><ed><U+00BF><U+00BB><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098>\r\r\n#showtimetourinhongkong #ikon #bi #bobby #chanwoo?https://t.co/75j71btWYy",
#  '<U+9EC3><U+660F> #<U+9EC3><U+660F>  #magichour #sunset #hongkong @ <U+7DAD><U+591A><U+5229><U+4E9E><U+6E2F> Victoria Harbour https://t.co/nulqQceAmM',
#  "I'm at AEON <U+6C38><U+65FA> in Kowloon City https://t.co/wFyBX0P1cr https://t.co/mYuQIWcX81",
#  'Happy Family. <ed><U+00A0><U+00BC><ed><U+00BF><U+00B0> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Disneyland Hk https://t.co/5OUST5aBRn',
#  'That\'s an actual "hello kitty" restaurant! #hongkong #TST #cantonroad @ Hello kitty <U+4E2D><U+83DC><U+8ED2> https://t.co/7GxVvoA7Ok',
#  '<U+5589><U+56A8><U+597D><U+75DB> @ <U+897F><U+8CA2><U+6D77><U+508D> https://t.co/eacAY8XsrN',
#  "The world's busiest shipping straits. The Zhujiang River Estuary. \r\r\n\r\r\n#hongkong #hkadventures?https://t.co/oCg4RWzFpQ",
#  '#HYPR | Brunch @grassrootshk.\r\r\n\r\r\n#brunch #vegetarian #vegan #menu #restaurant #style #design?https://t.co/YWltZA1Maa',
#  'When Peter gets so excited of all the purses you got to take him out and around! #hk #valentino?https://t.co/1lTHuxPDt4',
#  '<U+7CE7><U+5C3E><U+53C8><U+4E00><U+95DC> @ <U+5143><U+5DDE><U+5546><U+5834> https://t.co/5wEt4LiOjE',
#  'iGod (@ Hong Kong Industrial Centre <U+9999><U+6E2F><U+5DE5><U+696D><U+4E2D><U+5FC3> in Lai Chi Kok, Hong Kong) https://t.co/dHH92oGqTI https://t.co/XDmjrNcuah',
#  '160507  like a painting @ HK ifc mall <U+9999><U+6E2F><U+570B><U+969B><U+91D1><U+878D><U+4E2D><U+5FC3><U+5546><U+5834> https://t.co/ZfuHZwais5',
#  '<U+9EC3><U+660F> #<U+9EC3><U+660F> #magichour #tst #hongkong @ <U+7DAD><U+591A><U+5229><U+4E9E><U+6E2F> Victoria Harbour https://t.co/B0rj25KxKz',
#  '<U+5F88><U+4E45><U+6C92><U+4F86><U+4E86> (@ China-T <U+5C0F><U+96E8><U+5929> in Kwai Chung) https://t.co/morR4iIpvL',
#  'Not sure if the view is better from here or from our little?https://t.co/kp5ea3t2Hn',
#  'Ikon. Concert!! We are coming!! @ AsiaWorld\x96Expo https://t.co/IFt5fzPGKl',
#  'when you visit the Victoria Peak, how can you skip Burger King,?https://t.co/Mt8Qccxiav',
#  "I'm at Yee Shun Dairy Company <U+6E2F><U+6FB3><U+7FA9><U+9806><U+725B><U+5976><U+516C><U+53F8> in Causeway Bay https://t.co/P1LTEkD0iO",
#  'I <U+2764><U+FE0F> HK @ The Hong Kong Victoria Peak <U+9999><U+6E2F><U+592A><U+5E73><U+5C71><U+9802> https://t.co/QuBdFPoDM1',
#  "I'm at Isobar in Hong Kong https://t.co/x5J9PzYAFK",
#  'Catching up with the tropang balat. #Times33 #SembawangPips #WeMissYouPao @ Superstar Virgo https://t.co/lkvA3Sy6UD',
#  '<U+9858><U+4F60><U+4ECA><U+591C><U+5225><U+96E2><U+53BB><U+3002><U+3002><U+3002><U+3002> @ <U+6838><U+5FC3><U+5167><U+570D><U+51FA><U+9762><U+5605><U+6838><U+5FC3><U+5916><U+570D> https://t.co/vKfexf74xN',
#  'I just finished hiking 8.70 km in 3h:52m:58s with #Endomondo #endorphins https://t.co/45HkZf2H6f',
#  'Mustard crust spring lamb chops - garlic herb sauce #mustardcrusted #lambchops #food #foodporn?https://t.co/0bcUtl1a2V',
#  'Cajun spliced  chicken wings and onion rings #cajunspice #chickenwings #onionrings #food?https://t.co/0CkSJfmeAn',
#  '<U+4E00><U+9023>5<U+65E5>~~<U+9752><U+8863><U+5929><U+540E><U+5BF6><U+8A95>~~~ <ed><U+00A0><U+00BD><ed><U+00B8><U+0084>#bazaar #festival #style #hkig #iger #2016 #life #thisishongkong #TsingYi?https://t.co/zgXVpr9bfM',
#  'Really love this customized clutch by Cecilia Ma Couture. She has a wide collection of ready?https://t.co/0l0kzwKWLt',
#  'Bright. #lighting #interiors @ Carbone https://t.co/ZZPSDuMsIa',
#  'Bye Hongkong <ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0> @ <U+9999><U+6E2F><U+8D64><U+81D8><U+89D2><U+570B><U+969B><U+6A5F><U+5834> Hong Kong International Airport https://t.co/tpkEiReQdd',
#  '<U+6838><U+5FC3><U+5916><U+570D><U+270C> @ Leon 30TH Anniversary Random Love Songs 4D in Life 2016 https://t.co/SdhIcJJ8yz',
#  'Up on the #centraltomidleavelescalator - we thought this was\x85 https://t.co/zL1RTzEW9h',
#  '<U+73ED><U+53CB><U+597D><U+696D><U+9918>,<U+5572><U+9938><U+4FC2><U+9810><U+88FD><U+6240><U+4EE5><U+5473><U+9053><U+90FD><U+4F3C> (@ Simmer Huang Chinese Food <U+9EC3><U+8A18><U+714C><U+4E09><U+6C41><U+71DC><U+934B> in Hong Kong) https://t.co/xsfMl52X0A',
#  'The Peak. @ Hong Kong https://t.co/koNwzCPivw',
#  '#<U+7D2B><U+8272> #<U+4E94><U+89D2><U+661F> #<U+71D9><U+756B> #<U+5360><U+535C> #<U+5100><U+5F0F> #<U+796D><U+58C7><U+5E03>,<U+7D04>18<U+540B> #<U+6B63><U+65B9><U+578B>\r\r\n\r\r\n#Square #purple #velvet #pentacle #divination #ritual\x85 https://t.co/tCUiEKFCVu',
#  'This guy is #classy, bareing all!! @ Hong Kong Zoological and\x85 https://t.co/cMbE5z5jVt',
#  '<U+4E00><U+8DEF><U+4ECE>7<U+7EA7><U+8DCC><U+56DE>14,<U+8FD9><U+4ED6><U+5988><U+6CA1><U+6CD5><U+73A9><U+4E86>',
#  '<U+6C92><U+7A7A><U+53BB><U+53F0><U+7063>,<U+9084><U+597D><U+627E><U+5230><U+9019><U+500B><U+4F86><U+56DE><U+5473><U+4E00><U+4E0B> #<U+611B><U+53F0><U+7063> @ <U+5927><U+570D><U+706B><U+8ECA><U+7AD9> https://t.co/WU959x3Rid',
#  'the plates are small, but flavorful. after ordering 5 dishes, I ordered 5 more. totally worth\x85 https://t.co/C0DBVRPjP7',
#  "The last stop of #teppyscoffeeshoplist on this #HK trip. I'm pretty much super caffeinated this\x85 https://t.co/iJgKjbRhrz",
#  '<U+83AB><U+5948><U+4F5C><U+54C1>:<U+963F><U+723E><U+5CA1><U+7279><U+4F0A><U+706B><U+8ECA><U+7AD9> Claude Monet: The Railroad Station at Argenteuil #claudemonet #argenteuil\x85 https://t.co/XOt9HPsjHs',
#  "I'm at Kwai Chung Plaza <U+8475><U+6D8C><U+5EE3><U+5834> in Kwai Chung https://t.co/eHy4Kw2Gk7",
#  '#ikon live tour in hk 2016 <U+5F00><U+573A><U+524D> @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/AA6udVleda',
#  "Shy &amp; Bella were dancin'\r\r\n#candid #streetphotography #teppyinHK #travel #HK @ U Lam Terrace https://t.co/Y3hTqQKeZ4",
#  'Long time no go (@ Ho Ming Kee Restaurant <U+4F55><U+660E><U+8A18><U+7C89><U+9EB5><U+9910><U+5EF3> in Yuen Long) https://t.co/uIxbxillDE https://t.co/2A6WGJUKj6',
#  '<ed><U+00A0><U+00BD><ed><U+00B1><U+008D><ed><U+00A0><U+00BD><ed><U+00B1><U+008D> (at Victoria Harbour <U+7DAD><U+591A><U+5229><U+4E9E><U+6E2F>) [pic] \x97 https://t.co/mFNszKTAaP',
#  'this is the last cube of Kagoshima beef. filled with the buttery salt and sweetness of its\x85 https://t.co/tjBqkKmzXQ',
#  'Finally I met my <U+B3D9><U+C0DD> <U+D55C><U+BE44><U+B2C8> ~~~~~~<ed><U+00A0><U+00BD><ed><U+00B8><U+008A><ed><U+00A0><U+00BD><ed><U+00B8><U+008A><ed><U+00A0><U+00BD><ed><U+00B8><U+008A> @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/QeDxb3PvXg',
#  'Dinner tonight by chef Kat Kat <ed><U+00A0><U+00BD><ed><U+00B8><U+0081><ed><U+00A0><U+00BD><ed><U+00B8><U+0081><ed><U+00A0><U+00BD><ed><U+00B8><U+0081> 07May16 @ Boo Boo Kayla Sweet Home https://t.co/QGVbY07DUG',
#  'Really pleased with this Mango Lassi Pale Ale ! @ High Street, Sai Ying Pun https://t.co/93mGDBmeIS',
#  "Today's dinner is <U+4E7E><U+7092><U+725B><U+6CB3> Beef fried flat noodles. @ <U+9999><U+6E2F><U+98A8><U+60C5> - <U+6A5F><U+5834>2<U+865F><U+5BA2><U+904B><U+5927><U+6A13> https://t.co/SB7vF7fozO",
#  "Trekking-ish @ <U+9F8D><U+810A> Dragon's Back https://t.co/qd9vQv03bC",
#  '#brooding #sky #hongkonglife #kennedytown @ Instagram Pier https://t.co/VT3v6sYYdq',
#  'I just finished cycling 33.67 km in 2h:08m:49s with #Endomondo #endorphins https://t.co/XSEaCNDxZD',
#  'I wish you all a fantastic weekend from #hongkong .. || #hkg #china #asia #sunset #weekend\x85 https://t.co/tmOe7kTrdR',
#  "I'm at New Town Café 1884 <U+5C0F><U+57CE><U+5E74><U+4EE3> - @newtown1884 in Hung Hom, Hong Kong https://t.co/N9FEoKAUto",
#  'Beautiful British shorthairs at bangbang70s vintage store! Happy caturday! <U+2764><U+FE0F> #catsofinstagram\x85 https://t.co/xzzjoMLQVl',
#  "I'm at iDarts 3S' Air in Tsim Sha Tsui https://t.co/ikfayQ1SRU https://t.co/C5lTIq08Ye",
#  'Spa water - Drinking a Rose Oolong <U+73AB><U+7433> by Moonzen @ Centre Street Cooked Food Centre <U+6B63><U+8857><U+719F><U+98DF><U+4E2D><U+5FC3>  \x97 https://t.co/G6CIL820q7',
#  "This weeks #ARTonSUNDAY #selection \r\r\n#gallery #open from 4pm coz it's too #sunny to stay #indoors\x85 https://t.co/NNWnWfrLPw",
#  'Beach day with these weirdos <ed><U+00A0><U+00BD><ed><U+00B8><U+0084> #sheko #beach #hongkong @ Skek O Beach, Hong Kong https://t.co/ifIBtMNyOt',
#  "I'm at Piglet Dessert in <U+4E5D><U+9F8D> https://t.co/1kGqjg6HDJ https://t.co/Naznki0FiL",
#  'Really good noodles!!! (@ <U+6A4B><U+9999><U+5712><U+96F2><U+5357><U+6842><U+6797><U+904E><U+6A4B><U+7C73><U+7DDA> in Central, Hong Kong) https://t.co/VyUPBFm4Tv https://t.co/avrZtGnmqM',
#  "I'm at Chrisly Café <U+83EF><U+661F><U+5BA2><U+68E7> https://t.co/0qBLldKpBT",
#  '<U+4FC2><U+6838><U+5FC3><U+5916><U+570D><U+898B><U+5230><U+6838><U+5B50><U+8D85><U+8208><U+596E><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BD><ed><U+00B8><U+008D> @ <U+6838><U+5FC3><U+5916><U+570D> https://t.co/P1NQOwLvgS',
#  'Interested in a #Sales #job near #HongKong? This could be a great fit: https://t.co/VzeaU9ZtLE #Veterans #Hiring',
#  'How evil!!!!!!! @ <U+4F73><U+5BE7><U+5A1C><U+6F6E><U+5DDE><U+9152><U+6A13> https://t.co/TDxJm080qZ',
#  'IKON ready to blow!! #ikon #expo #concerttime hongkong @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/ea0CghVDGg',
#  '# B e a c h <ed><U+00A0><U+00BD><ed><U+00B8><U+008E> @ Repluse Bay https://t.co/UQKG4cRnpF',
#  '<U+4E4B><U+524D><U+53BB><U+65E5><U+672C><U+4FFE><U+6D77><U+95DC><U+6536><U+5DE6><U+628A><U+5341><U+5B57><U+5200>,<U+800C><U+5BB6><U+8CB7><U+628A><U+6709><U+6307><U+7532><U+526A><U+65E2>,<U+5E73><U+65E5><U+90FD><U+7528><U+5F97><U+5230><U+3002> @ Victorinox https://t.co/NcVT94tvCM',
#  "I'm at The @RitzCarlton, Hong Kong in West Kowloon https://t.co/tJdT8EY1Ba",
#  '# B e a c h <ed><U+00A0><U+00BD><ed><U+00B8><U+008E><ed><U+00A0><U+00BD><ed><U+00B8><U+008E> @ Repluse Bay https://t.co/iYHYUl44zx',
#  'Alice in Wonderland Party (@ Ozone - @ritzcarlton in West Kowloon) https://t.co/kY6pDf8NuS',
#  '<U+7B49>,<U+7B49>,<U+7B49> (@ Shugetsu <U+5468><U+6708> in Central) https://t.co/deARUiapUT',
#  '.\r\r\n<U+8D70><U+51FA><U+4E86><U+4E00><U+5E74><U+524D><U+7684><U+4F4E><U+8C37>\r\r\n<U+8FCE><U+4F86><U+7B2C><U+4E00><U+500B><U+9AD8><U+5C71>\r\r\n<U+8F49><U+773C><U+8D70><U+5B8C><U+4E86>,<U+773C><U+524D><U+770B><U+5230><U+7684><U+8DEF><U+4F3C><U+662F><U+6025><U+8F49><U+76F4><U+4E0B>\r\r\n\r\r\n<U+5927><U+6982><U+8981><U+8D70><U+5230><U+53E6><U+4E00><U+500B><U+9AD8><U+5C71><U+5FC5><U+9808><U+5148><U+7D93><U+904E><U+4E0B><U+4E00><U+500B><U+4F4E><U+8C37>\r\r\n<U+4F46><U+9858><U+9806><U+8457><U+9019><U+8D70><U+80FD><U+4E00><U+5207><U+5B89><U+597D><U+3002>\r\r\n#parkes #kris #lastday\x85 https://t.co/loGAYsiDou',
#  'Get ready showtime<ed><U+00A0><U+00BD><ed><U+00B8><U+008E>\r\r\n#iKON #showtime #showtimetour #iKONCERT #bobby #bi #jinhwan #june #chanwoo\x85 https://t.co/xVfTU25HDG',
#  '"NO  language can express the power and beauty and heroism of a\x85 https://t.co/Xl9qNYUVZ1',
#  'Need more converse shoes',
#  "Let's join the fun. Civil War. <ed><U+00A0><U+00BD><ed><U+00B1><U+008A><ed><U+00A0><U+00BD><ed><U+00B1><U+008A><ed><U+00A0><U+00BD><ed><U+00B1><U+008A> @ Cityplaza Hong Kong https://t.co/3UlcvB7r4G",
#  'Fat beef!!! #hkdining @ <U+4F73><U+5BE7><U+5A1C><U+6F6E><U+5DDE><U+9152><U+6A13> https://t.co/mmf7afkNUf',
#  "I'm at Discovery Bay Ferry Pier <U+6109><U+666F><U+7063><U+6E21><U+8F2A><U+78BC><U+982D> in Discovery Bay https://t.co/Zvi6hvero5",
#  '<U+4E00><U+500B><U+7537><U+4EBA><U+55BA><U+75C5><U+7DCA><U+5605><U+8001><U+5A46><U+9762><U+524D><U+98DF> #<U+9E7D><U+9165><U+96DE> <ed><U+00A0><U+00BD><ed><U+00B8><U+00A1><ed><U+00A0><U+00BD><ed><U+00B8><U+00A1><ed><U+00A0><U+00BD><ed><U+00B8><U+00A1>\r\r\n#<U+6211><U+90FD><U+597D><U+60F3><U+98DF><U+9E7D><U+9165>g\r\r\n#<U+4F46><U+6211><U+5514><U+60F3><U+518D><U+7E7C><U+7E8C><U+98DF><U+85E5> <ed><U+00A0><U+00BD><ed><U+00B2><U+008A> @ <U+6D2A><U+7956><U+5E2B><U+64D4><U+4ED4><U+9EB5> - <U+4E0A><U+6C34><U+5E97> https://t.co/td0ONPN4TQ',
#  "I'm at The Upper House <U+5955><U+5C45> in Central https://t.co/uTbX1O55EL",
#  'Happy to attend the mercedesbenzhk SLC43 launch last night with the team from @prestige_hk at\x85 https://t.co/MMFXdSn0Y4',
#  "I'm at Café Gray Deluxe in Central https://t.co/c9ixWe7h6I",
#  "I'm at El Loco Gringo w/ @m4grio @lzmx @javgloria https://t.co/cVtTc23Dlu",
#  'Old style fried chicken #hkdining @ <U+4F73><U+5BE7><U+5A1C><U+6F6E><U+5DDE><U+9152><U+6A13> https://t.co/SHdbc1XMRp',
#  'We are back <ed><U+00A0><U+00BD><ed><U+00B8><U+008A> @ Ta Vie <U+65C5> https://t.co/jQgamyxm89',
#  'Eew... Eel!!! #hkdining @ <U+4F73><U+5BE7><U+5A1C><U+6F6E><U+5DDE><U+9152><U+6A13> https://t.co/Kq1rKIdNpU',
#  'Leon Leon Leon Leon........ @ <U+4E2D><U+74B0><U+6D77><U+6FF1><U+6D3B><U+52D5><U+7A7A><U+9593> https://t.co/74Y9XBThmP',
#  '<U+4ECA><U+665A><U+8981><U+611F><U+53D7><U+4E0B><U+5916><U+570D><U+6C23><U+6C1B><U+5148>!<ed><U+00A0><U+00BC><ed><U+00BE><U+00A4><ed><U+00A0><U+00BC><ed><U+00BE><U+00A4><ed><U+00A0><U+00BC><ed><U+00BE><U+00A4><ed><U+00A0><U+00BC><ed><U+00BE><U+00BC><ed><U+00A0><U+00BC><ed><U+00BE><U+00BC><ed><U+00A0><U+00BC><ed><U+00BE><U+00BC> @ <U+6838><U+5FC3><U+5916><U+570D> https://t.co/Nmuiygdw6l',
#  '<U+6B21><U+6B21><U+540C><U+4F60> karylyt_ <U+884C><U+8857><U+90FD><U+53EF><U+4EE5><U+64CB><U+597D><U+591A><U+707D><ed><U+00A0><U+00BD><ed><U+00B1><U+00BC><ed><U+00A0><U+00BC><ed><U+00BF><U+00BC> #<U+5047><U+5982><U+7834><U+8CA1><U+540C><U+64CB><U+707D><U+6210><U+6B63><U+6BD4><U+7684><U+8A71><ed><U+00A0><U+00BE><ed><U+00B4><U+0091><ed><U+00A0><U+00BE><ed><U+00B4><U+0091><ed><U+00A0><U+00BE><ed><U+00B4><U+0091> @ School Food Hong Kong https://t.co/XbKxklyFeU',
#  'We just like to drink. \r\r\n\r\r\n#dinner #hk #hkig #wineoclock #moments #love #life #photooftheday #hk\x85 https://t.co/pPGbOXQ8zL',
#  'Oops... But I am ready for summer lol (@ GigaSports in Tsim Sha Tsui) https://t.co/FPSplVpzpL',
#  'Dinner ready Daddy B <ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BD><ed><U+00B8><U+008D> 07May16 @ Boo Boo Kayla Sweet Home https://t.co/5xQIUqKo9V',
#  'After a long day of walking, nothing beats a traditional Chinese foot massage #awesome #hongkong\x85 https://t.co/K7FrqTbWBL',
#  "willjaymusic interview finally finished and ready to go. It'll be online on Monday and only on\x85 https://t.co/17SdX9QpbK",
#  'Just posted a video @ AsiaWorld\x96Expo https://t.co/Qu4UnISRDk',
#  'Mango Aroma <U+2763> @ MOKO <U+65B0><U+4E16><U+7D00><U+5EE3><U+5834> https://t.co/mXRVIt2PLR',
#  'Just posted a photo @ Ozone at The Ritz-Carlton, Hong Kong https://t.co/bzO1rRmopE',
#  "I'm at International Commerce Centre <U+74B0><U+7403><U+8CBF><U+6613><U+5EE3><U+5834> in West Kowloon https://t.co/YpGcLRH1pt",
#  "I'm at Ozone - @ritzcarlton in West Kowloon https://t.co/f4r6OvewT2",
#  "I'm at The Ritz-Carlton, Hong Kong in West Kowloon https://t.co/iKrbvwhlLo",
#  '<ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0> @ Second Street Sai Ying Pun https://t.co/ygmNcZVGxg',
#  '[hong kong] Vintage Burger @ Food Truck Festival, PMQ.\r\r\n\r\r\n#hkfood #hkfoodlover #food\x85 https://t.co/utynFHBPJo',
#  'Yeungs #siblings #siswedding @ Holy Cross Catholic Church <U+8056><U+5341><U+5B57><U+67B6><U+5802> https://t.co/cwOPCVGJKD',
#  "I'm at IFC Mall <U+570B><U+969B><U+91D1><U+878D><U+4E2D><U+5FC3><U+5546><U+5834> - @hkifcmall in Hong Kong https://t.co/hWZRI6yPBx",
#  'Bello~\r\r\n\r\r\n#minions #bob #king #<U+570D><U+57CE><U+826F><U+59BB><U+65E5><U+8A18> #<U+66F8><U+5E97> #banana #happyday @ MOKO <U+65B0><U+4E16><U+7D00><U+5EE3><U+5834> https://t.co/BNLf845nS6',
#  "I'm at Korean Canteen https://t.co/BKz1hxluvJ https://t.co/WIGhrYMIxN",
#  'You never fail to amaze me HK<ed><U+00A0><U+00BC><ed><U+00BC><U+0083> @ Avenue of Stars, Hong Kong https://t.co/sTmA6g8JKE',
#  '"Ho Lee Fook" he said. "Good fortune for your mouth" it said. I totally though it was a joke (or\x85 https://t.co/MjiMt8zbPk',
#  'Enjoy the impromptu cafe hopping with my girls <U+2615><U+FE0F> @ Peel Street Espresso Bar https://t.co/lTYrSCszDM',
#  'Pre-cooked meaty goodness for dinner (@ Taste in Tung Chung) https://t.co/q1SBx3Gd6U https://t.co/vgaeZzofW6',
#  'PHOON at Colin Phils : 2016 China Tour Hong Kong Station w/ Emptybottles. &amp; PHOON\x85 https://t.co/zgCYlUxmP1',
#  'Come to a beer pub and order wine? What a joke!<ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BC><ed><U+00BD><U+00BA><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BC><ed><U+00BD><U+00BA><ed><U+00A0><U+00BD><ed><U+00B8><U+0082>\r\r\n\r\r\n#Brewdog #beer #HongKong #travel\x85 https://t.co/zrJmxCEKVv',
#  "It's a thing of real tasty beauty. Patbingsu (<U+D325><U+BE59><U+C218>) or red beans with ice for #dessert. So light,\x85 https://t.co/lkPFnRv5GF",
#  "Here's looking at cha.\r\r\n\r\r\n#candid #streetphotography #mural #HK #teppyinHK #travel #HongKong @\x85 https://t.co/zKC9HluqL4",
#  "I'm at MTR Lo Wu Station <U+7F85><U+6E56><U+7AD9> in Lo Wu https://t.co/edUNF5N2Q0",
#  "I'm at Central Pier No. 7 (Star Ferry) <U+4E2D><U+74B0>7<U+865F><U+78BC><U+982D>(<U+5929><U+661F><U+5C0F><U+8F2A>) in Central https://t.co/0yREZRgnH7",
#  'Dinner (@ my wine man) https://t.co/TrfpNSMd5N https://t.co/pwaWpk7kuC',
#  '<U+5FC3><U+60C5><U+9B31><U+60B6><U+5C31><U+8981><U+98DF><U+80A5><U+53C9><U+6CB9><U+96DE><U+98EF> <U+53C9><U+71D2><U+5165><U+5473> <U+6CB9><U+96DE><U+5AE9><U+6ED1> <U+52A0><U+500B><U+751C><U+8C49><U+6CB9><U+52A0><U+8591><U+84C9><U+6488><U+98EF> <U+4E00><U+6D41>\r\r\n#<U+86C7><U+738B><U+4E8C> #<U+55AE><U+62D6><U+98DF><U+98EF> #<U+81BD><U+56FA><U+9187><U+4EBA><U+751F> @ <U+86C7><U+738B><U+4E8C><U+86C7><U+7FB9><U+5C08><U+5BB6> https://t.co/HaJ818tvdH',
#  '#travel #teppyinHK #HK #hongkong @ Hongkong Museum of Medical Sciences https://t.co/BRPFQJy9Qe',
#  '#happymathersday #dinner @ <U+6D77><U+6F84><U+8ED2><U+5929><U+6F84><U+95A3><U+95A3><U+4E2D><U+83DC><U+5EF3> https://t.co/Ig3Kf3tpt3',
#  '<U+7A76><U+7ADF><U+6211><U+53BB><U+5497><U+7747><U+5973><U+5718><U+5B9A><U+7537><U+5718><ed><U+00A0><U+00BD><ed><U+00B8><U+0082>\r\r\n#<U+7537><U+626E><U+5973> #iKON #showtime #showtimetour #iKONCERT #bobby #bi #jinhwan #june #chanwoo\x85 https://t.co/NxEN697NC2',
#  'Pre<U+6BCD><U+89AA><U+7BC0> Lunch~<U+540C><U+5ABD><U+5ABD><U+51FA><U+7063><U+4ED4><U+98DF><U+65E5><U+672C><U+91CE>:) <U+6211><U+5730><U+5169><U+500B><U+5305><U+5834><U+56C9>! PP<U+5481><U+904E><U+6BCD><U+89AA><U+7BC0><U+53C8><U+5982><U+4F55>,\x85 https://t.co/HmKkmYgZcQ',
#  'Boxing is a continuous journey of learning. My most gratifying lesson was to find out that my\x85 https://t.co/3b2ksbUzFP',
#  "07.05.2016 SAT 09:36pm\r\r\nLove Me Like You Do-Ellie Goulding/jaykiman Choreography\r\r\n/\r\r\nIt's\x85 https://t.co/WQX8kppTja",
#  'Gray skies overcasting the whole city @ Victoria Harbour Hongkong https://t.co/ThrgTkzg6k',
#  '#Repost @dolceandbanana with repostapp\r\r\n···\r\r\nThis photo is missing Beckaly, but all I can say is\x85 https://t.co/mbD63tD2AL',
#  'Underneath the purple sky I win my final league match 6-2, 2 wins this evening.  Good luck team,\x85 https://t.co/Cp3wn3sw09',
#  '<U+56E0><U+70BA>#<U+592A><U+967D><U+7684><U+5F8C><U+88D4> <U+56E0><U+70BA> #100<U+6BDB> <U+9127><U+9E97><U+6B23><U+689D><U+690D><U+5165><U+5F0F><U+5EE3><U+544A><U+7247>,<U+6211><U+53C8><U+5FCD><U+5514><U+4F4F><U+8CB7><U+5497> #Laneige BB Cushion, <U+5E7E><U+6642><U+90FD><U+8A71> #<U+5973><U+4EBA><U+9322><U+6700><U+6613><U+8CFA> @ Laneige https://t.co/YAKusCyUhy',
#  'After Superfood I feel superfull #superfood #djyin @ nood food https://t.co/s8AIBsf3D2',
#  'Emptybottles. at Colin Phils : 2016 China Tour Hong Kong Station w/ Emptybottles. &amp; PHOON\x85 https://t.co/qqpNYiTF2C',
#  '<U+6232><U+68DA><U+5572><U+5622><U+98DF><U+597D><U+649A><U+591A><U+5473><U+7CBE> (@ ideas Dessert in <U+8343><U+7063>) https://t.co/7cB6osmROS https://t.co/kCyVJAlNKI',
#  '<U+6232><U+68DA><U+5572><U+5622><U+98DF><U+597D><U+649A><U+591A><U+5473><U+7CBE> (@ ideas Dessert in <U+8343><U+7063> w/ @forkthin) https://t.co/fnN9CJIFJi https://t.co/fpkIZwCGoJ',
#  'My first experience of an traditional family function in HK .\x85 https://t.co/7NnS88blsi',
#  'Welcome to HK! @choktweets @ The Excelsior, Hong Kong https://t.co/RPkePfw8TN',
#  'Here is another one <ed><U+00A0><U+00BD><ed><U+00B8><U+008D> #HONGKONG #favouritepeople #Igotthis @ Hong Kong https://t.co/1WFx0hZb2R',
#  'Climax <ed><U+00A0><U+00BC><ed><U+00BF><U+00B3><ed><U+00A0><U+00BD><ed><U+00B2><U+0099><U+2728> (at @asiaworldexpohk) [pic] \x97 https://t.co/I7pA9csZIF',
#  "HTC 10 sounds fantastic, music lovers, this is the phone you'll want",
#  '#last day (@ Leon 30th Anniversary Random Love Songs 4D in Live) https://t.co/5mlbmjWDUy',
#  "I'm at The Hong Kong Observation Wheel <U+9999><U+6E2F><U+6469><U+5929><U+8F2A> in Central, Central and Western District https://t.co/fuuOuhzFlf",
#  '<U+8001><U+8C46>,<U+7540><U+5572><U+6548><U+7387><U+569F> Okay<U+FF1F><ed><U+00A0><U+00BD><ed><U+00B8><U+0082> #<U+901F><U+5EA6><U+7684><U+91CD><U+8981><U+6027> #HappyMothersDay #455Days @ Baby Café https://t.co/Es1FQX1D1z',
#  "Kids favourite meal! <U+2764><U+FE0F> Recipe in next week's meal plan - coming soon! <ed><U+00A0><U+00BD><ed><U+00B8><U+0089> #dinner #chorizo\x85 https://t.co/xJDHHfbgS3",
#  '<ed><U+00A0><U+00BD><ed><U+00B8><U+008D> @ <U+9999><U+6E2F><U+8FEA><U+58EB><U+5C3C><U+6A02><U+5712> Hong Kong Disneyland Resort https://t.co/gwLvIhEbx9',
#  "I'm at MTR Kowloon Tong Station in Kowloon Tong https://t.co/fosm5VANey",
#  "I'm a live MSG tester. (@ <U+69AE><U+5712><U+9EB5><U+5BB6> in Mong Kok) https://t.co/nTpAiWiZgU",
#  'Another nice cafe in Central. <U+2615><U+FE0F> @ Peel Street Espresso Bar https://t.co/dfUdAWrW1v',
#  'Colin Phils : 2016 China Tour Hong Kong Station w/ Emptybottles. &amp; PHOON #musicsurveillance\x85 https://t.co/KwvPFqapC3',
#  '#pekingduck which was really quite good!!! @ Peking Garden Restaurant https://t.co/i3nWtIHyfj',
#  '<U+3010><U+4EBA><U+4EBA><U+6709><U+4EFD><U+9A5A><U+559C>iPhone<U+512A><U+60E0><U+3011> \r\r\n<U+7121><U+6CD5><U+53EF><U+4FEE><U+98FE><U+7684><U+4E00><U+5C0D><U+624B>~<U+5E36><U+51FA><U+6EAB><U+6696><U+6C38><U+9060><U+5728><U+80CC><U+5F8C>\r\r\n<U+300C><U+5049><U+5927><U+6BCD><U+89AA><U+89AA><U+611B><U+4E94><U+6708><U+8AA0><U+610F><U+63A8><U+4ECB><U+300D>\r\r\niPhone <U+7F8E><U+570B><U+884C><U+8CA8> <U+5404><U+578B><U+865F><U+512A><U+60E0><U+51FA><U+552E>\r\r\n<U+300C><U+8AA0><U+610F><U+7279><U+50F9><U+51FA><U+552E><U+516C><U+53F8>DEMO<U+6A5F><U+300D>\r\r\nApple\x85 https://t.co/ZIXug3nvu7',
#  'Conquering Hongkong.\r\r\nWhere are my #stormtrooper ?\r\r\n@varganation \r\r\n#hongkong #harbour #harbourview\x85 https://t.co/DQ98hLHSd9',
#  "I'm at Liu Yuan Pavilion <U+7559><U+5712><U+96C5><U+6558> in Wan Chai https://t.co/n8YwFVe376",
#  'At last, TeaTime ! #LaterGram #ILoveHK @ The Parlour @ Herritage 1881 https://t.co/xOz9NvSbxI',
#  'Stop 1: So good I had to come back and have my last night in #HK @legarconsaigon #hkeats\x85 https://t.co/5evtEaefV8',
#  'Yellow chicken wrapped, kurobuta pork skewers, green papaya salad, hedgehog mushrooms\x85 https://t.co/abhkj3jOQo',
#  '#cantonese#chinese##hongkong#hkgirls##sky#selfie#style#studio#studiolife#recording##artist#singer\x85 https://t.co/KZNkOKrHhC',
#  'Stop 2: @littlebaohk #hkeats #restauranthopping #hongkong @ Little Bao https://t.co/AtxxuoIX1W',
#  'N.I.G.H.T. Looking for just a hint of fresh air on 25th floor #pépetteàhongkong #hongkong\x85 https://t.co/iZtCRNwWQU',
#  '@KwongChinFung built in speakers does produce that tweeter and bass feel, headphone is fantastic, details are crisp and output is great',
#  'Remembering the #goodtimes #goodvibes #goodfriends\x85 https://t.co/mqm4aGrn01',
#  'Welcome dinner with @choktweets and mardonesc @ Tango Argentinian\x85 https://t.co/jXe2rQFaU9',
#  'Beautiful sunset on our way to #hongkong #asiaworldcity #lifewelltravelled #cx #airbus330\x85 https://t.co/3UTgNjU4Tv',
#  'enjoying a glass of Baileys and a jar of green tea on a Saturday\x85 https://t.co/RZzLW9YIJZ',
#  'Surreal!! <ed><U+00A0><U+00BD><ed><U+00B8><U+008D><ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0>  #victoriapeak #thepeak #hongkong #hongkonglife #travel #asyongawesometravel # @\x85 https://t.co/1uDiEjrmrQ',
#  'I <U+2764><U+FE0F><ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0>\r\r\n#ilovehongkong #hongkong @ WooLooMooLoo Rooftop Bar - 31/F https://t.co/NkIkAxENaj',
#  'Saturday night fever #KowloonCity Limits.\r\r\n\r\r\n#hongkong #nofilter <ed><U+00A0><U+00BD><ed><U+00B3><U+00B7>: #jjiphone6s @ Kowloon City Park https://t.co/FJmvPHwa7z',
#  '<U+521D><U+4E00><U+8981><U+98DF><U+7D20><U+3002><U+89C0><U+5858><U+65B0><U+958B><U+7684> #vegglecafe <U+4E0D><U+932F>,<U+6C99><U+5F8B><U+83DC><U+65B0><U+9BAE>,<U+8543><U+85AF><U+689D><U+54B8><U+54B8><U+751C><U+751C><U+7684><U+4E0D><U+932F><U+5403><U+3002><U+4EE5><U+5F8C><U+53C8><U+591A><U+4E00><U+500B><U+98EF><U+5802><U+4E86><U+3002>\r\r\n\r\r\n#veggie #vegetarian #igdaily #iggirl\x85 https://t.co/CDEPVwkHmS',
#  'I am so so sorry.......<ed><U+00A0><U+00BD><ed><U+00B8><U+00A2>\r\r\n<U+6211><U+53EA><U+4FC2><U+7D93><U+904E><U+5462><U+5EA6><U+8FD4><U+5C4B><U+4F01>\x85 https://t.co/LgVhj8mCnu',
#  "<U+6253>cream <U+5462><U+500B><U+7BC0><U+76EE>,<U+4E00><U+665A><U+6253><U+5169><U+6B3E><U+4FC2><U+6975><U+9650><U+3002><U+3002><U+3002> @ Q's Aroma https://t.co/lkAzJSEY4u",
#  'A great day in Ocean Park. It is awesome to get rid of those\x85 https://t.co/2oNMO03f77',
#  '@trimbach wine dinner hosted by Mr. Joel Payne @ Ozone at The Ritz-Carlton, Hong Kong https://t.co/48tMkGnWr2',
#  '#ikon live tour <ed><U+00A0><U+00BC><ed><U+00BE><U+00A4><ed><U+00A0><U+00BC><ed><U+00BE><U+0089><ed><U+00A0><U+00BD><ed><U+00B8><U+0082> @ <U+4E9E><U+6D32><U+570B><U+969B><U+535A><U+89BD><U+9928> Asia-World Expo https://t.co/uDNJER6Z1B',
#  "#HappyMothersDay to two of the most amazing #moms on the planet! <ed><U+00A0><U+00BD><ed><U+00B2><U+0090><ed><U+00A0><U+00BD><ed><U+00B8><U+009A><ed><U+00A0><U+00BC><ed><U+00BE><U+0082><ed><U+00A0><U+00BD><ed><U+00B2><U+0090><ed><U+00A0><U+00BC><ed><U+00BD><U+00BE><U+2763>\r\r\n#<U+6BCD><U+89AA><U+7BC0><U+5FEB><U+6A02> @ <U+7559><U+5BB6><U+5EDA><U+623F> Kin's Kitchen https://t.co/CYqDjgRXFr",
#  'Another fantastic meal <ed><U+00A0><U+00BD><ed><U+00B8><U+008A> love the firefly squid Caesar salad, beef tenderloin and white\x85 https://t.co/spABxnvO2o',
# ...
#  'Just posted a photo @ Orange Peel https://t.co/fPlThqKy3X',
#  '#mealprep @ Blue Roof https://t.co/Ivf3wUTH1R',
#  'Just posted a photo @ Orange Peel https://t.co/MrsUh5TDAS',
#  'Just posted a photo @ Orange Peel https://t.co/cDvOlDmGLo',
#  '@jyheffect @jungyh_ <U+4ECA><U+5929><U+662F><U+6BCD><U+89AA><U+7BC0><U+3002><U+665A><U+4E0A><U+5C31><U+5403><U+76C6><U+83DC><U+5BB4><U+3002><U+771F><U+7684><U+597D><U+597D><U+5473><U+5440>!<U+6211><U+98DF><U+9B91><U+9B5A><U+6700><U+591A><U+3002>Yeah ! <U+5927><U+6EFF><U+8DB3><U+3002><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082> <U+795D><U+9858><U+5404><U+6BCD><U+89AA> : <U+8EAB><U+4F53><U+5065><U+5EB7>,<U+9752><U+6625><U+7F8E><U+4E3D><U+3002><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098> #<U+76C6><U+83DC>\x85 https://t.co/PmNTBxHShh',
#  '<U+26C5><U+FE0F><ed><U+00A0><U+00BC><ed><U+00BC><U+00A4><U+2600><U+FE0F> @ Instagram Pier https://t.co/pSKE1xUzUv',
#  "Extra special Mother's Day with my mom &amp; grandma! <ed><U+00A0><U+00BD><ed><U+00B2><U+009C> @ Tsim Sa Tsui, Hong Kong https://t.co/4TczCD3qFR",
#  '#<U+6BCD><U+89AA><U+7BC0><U+5FEB><U+6A02># \r\r\n#family #happymothersday #supermum #celebration #loveyou #happyday #thankyou @ Cafe One\x85 https://t.co/osCSonKQoU',
#  "happy mother's day Momma Ho <ed><U+00A0><U+00BD><ed><U+00B1><U+00AA> thank you for always being there for\x85 https://t.co/QPT1CIoluE",
#  '#OOTD at hku..\r\r\nFeel free in everything...\r\r\n#instagram #instalike #instamood #instamag #instadaily\x85 https://t.co/sUXJgaOuCg',
#  "i am so amaze with ma self!\r\r\ncan't believe this is me. !! @ Hong Kong https://t.co/9jkXN7Dywd",
#  'Hipsters catchup, including the gangster Little Bae! #Friends #GoodFood #CreativeTypes\x85 https://t.co/lNPAGVWaSh',
#  "What a wonderful day at the beach! I'm pretty easy to please!! Happy Mother's Day! @ Big Wave\x85 https://t.co/VV0Tvcmw6T",
#  'See the unseen#elements#hongkong @ Element https://t.co/7D827Ty5F8',
#  "I'm at Nai Chung <U+6CE5><U+6D8C> in Ma On Shan, NT https://t.co/HadD7HGZxw",
#  '<ed><U+00A0><U+00BC><ed><U+00BD><U+0089> #watermelon #foodtruck #pmq #pmqhk #pmq<U+5143><U+5275><U+65B9> #fruitjuice #instafood #foodstagram @ PMQ <U+5143><U+5275><U+65B9> https://t.co/QM2tki6Syy',
#  'dad! happy birthday! @ Fairview Park Yuen Long https://t.co/IafFzrhCzQ',
#  'Jenny Czech again! more at https://t.co/fBOcaQSgSA #boudoir #boudoirmodel #boudoirphotography\x85 https://t.co/DoEu4fAzbc',
#  'T O U C H D O W N <ed><U+00A0><U+00BD><ed><U+00BB><U+00AC> @ Hong Kong International Airport https://t.co/yDY0eYwv7x',
#  "I'm at Pastis in Central https://t.co/aExBJ8xKv4",
#  'Hello there sweet lil baby Daenerys Arabella! <ed><U+00A0><U+00BD><ed><U+00B8><U+0099> Congrats to the new\x85 https://t.co/Vaz4W47aDW',
#  '1st Day Nlighten beauty product Sales in HongKong \r\r\n$12,200 total\r\r\nTo God be the Glory!\x85 https://t.co/iiF2cEJiDl',
#  'Happy #MothersDay from the finest #steakhouse in town.\r\r\n\r\r\n#PorterhouseByLaris #lkf #lankwaifong\x85 https://t.co/MaGM1C6j5I',
#  "Celebrating Mother's Day with friends..\r\r\nAgain Happy Mother's Day To all Mom's out there..<ed><U+00A0><U+00BD><ed><U+00B8><U+0098> @\x85 https://t.co/9TQgVjJ0wS",
#  'Happy towel dispenser\r\r\n\r\r\n#facesinthings @ Virgin Atlantic Clubhouse - Hong Kong https://t.co/2wEgz6DXYM',
#  'Together #family #love #cute #life #fashion #mothersday #friends #instalike #instagram\x85 https://t.co/xafG5N59tY',
#  '<U+540D><U+724C><U+5514><U+597D><U+53BB><U+5B78><U+4EBA><U+505A><U+751C><U+54C1>,<U+6709><U+5920><U+7684><U+96E3><U+98DF>!<U+5F97><U+500B><U+6A23>!<U+9664><U+5DE6><U+7CD6><U+5C31><U+53EA><U+6709><U+7CD6>\r\r\n#<U+96E3><U+98DF> #agnesb #<U+5514><U+4FC2><U+4ECA><U+65E5><U+98DF> #<U+5F97><U+500B><U+6A23>\r\r\n#<U+5514><U+6703><U+518D><U+53BB> @ New Town Plaza https://t.co/p68OXhn99t',
#  'Just posted a photo @ Wyndham Street https://t.co/urg1EDzE22',
#  '<U+7747><U+569F><U+4F62><U+597D><U+60F3><U+53BB><U+65C5><U+884C> @ <U+897F><U+8CA2> Sai Kung https://t.co/YVqy7YlnoK',
#  'Post concert dinner @ Pizza Express Wellington https://t.co/yjU73njM2g',
#  'Just another Sunday afternoon.. Girls trip #groupie @ Hung Hom, Hong Kong https://t.co/pSUBiJSXEy',
#  '<U+597D><U+773C><U+7793> (@ Hong Kong International Airport <U+9999><U+6E2F><U+570B><U+969B><U+6A5F><U+5834> (HKG) - @hkairport in Islands District, Hong Kong) https://t.co/2rjb7bLbGV',
#  'Finally after a long day!\r\r\n#unwind #ineedthis #ideserveit #finally #wooloomooloo #wine #letsdrink\x85 https://t.co/DyWAUlG1yL',
#  "Mother's Day dinner with this crazy mommies of my life. It's nice to\x85 https://t.co/HfMXF1KbZi",
#  '<U+6BD4><U+4E00><U+500B><U+5373><U+8208>R<U+6211><U+51FA><U+9ECE><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082>\r\r\n<U+6839><U+4F4F><U+53E6><U+4E00><U+500B><U+9ECE><U+958B><U+67F4><U+7063>,\r\r\n<U+6BD4><U+6211>R<U+57CB><U+6211><U+9ECE><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082> @ <U+9326><U+5C1A><U+751C><U+67F4><U+7063> https://t.co/1Vb7Gdx8j5',
#  'This how Mareie treats me on my special day. <ed><U+00A0><U+00BD><ed><U+00B8><U+0082> #happymothersday @\x85 https://t.co/NVqVoTctRm',
#  '8 may 2016 .. hongkong<U+2708><U+FE0F> #hongkong#holiday#traveling \r\r\n@nonangie @titharendriana @augustine_sukma\x85 https://t.co/ohTLj46VAy',
#  '3.6 <U+725B><U+4E73><U+62C9><U+9EB5>,<U+672C><U+4F86><U+62B1><U+4F4F><U+6709><U+9EDE><U+6311><U+6A5F><U+5FC3><U+614B><U+9078><U+9019><U+500B>,<U+4E0D><U+904E><U+6E05><U+6E05><U+5730><U+751C><U+751C><U+5730><U+53C8><U+5E7E><U+597D><U+98DF>,<U+9023><U+6E6F><U+90FD><U+5DEE><U+5572><U+98F2><U+6652> @ <U+5BCC><U+5C71><U+9EB5><U+5BB6> Ramen Iroha HK https://t.co/yvSZqM6Zv2',
#  'Just posted a photo @ Turbojet - Hong Kong Macau Ferry https://t.co/RB1fH62qL1',
#  'Just posted a photo @ Central Station HongKong https://t.co/G3p7Nm9b8l',
#  'Just posted a photo @ Sunny Bay Disney Land Resort https://t.co/eG6qP91gIv',
#  'Oh god rofl',
#  'Until we meet again, HK! <ed><U+00A0><U+00BD><ed><U+00B2><U+0095><ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0>\r\r\n#SummerInHK @ H.K. International Airport https://t.co/y9gCh78XdH',
#  'reminiscing those good memories during childhood time when i was up there but the view was\x85 https://t.co/NGfoWyoegu',
#  'Trying to match every #disney #legominifigures with the corresponding #medicomtoy product ...\x85 https://t.co/HifXjNUnd9',
#  'Happy mother day<ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098>love u love u love love\x85 https://t.co/El5WNfqjEZ',
#  'Conserve water, drink margaritas! <ed><U+00A0><U+00BD><ed><U+00B8><U+0089><ed><U+00A0><U+00BD><ed><U+00B8><U+0080><ed><U+00A0><U+00BC><ed><U+00BD><U+00B9>\r\r\n\r\r\n#margaritas #tequila #hongkong @ Hong Kong Brew House https://t.co/WJ0IlbGwjJ',
#  'Buy now or cry later <ed><U+00A0><U+00BD><ed><U+00B8><U+0089><ed><U+00A0><U+00BD><ed><U+00B1><U+0097><ed><U+00A0><U+00BD><ed><U+00BB><U+008D> #treatyoself #zara #vsco #vscocam #vscoph @ Ifc Mall Central Hongkong https://t.co/VcY1isgoUj',
#  "Happy Mother's Day <ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098><ed><U+00A0><U+00BD><ed><U+00B8><U+0098> @ <U+8B9A><U+8A18><U+5EDA><U+623F> https://t.co/PVR6thA1FT",
#  'Ako PANGO?? Since Birth.<ed><U+00A0><U+00BD><ed><U+00B1><U+008C><ed><U+00A0><U+00BD><ed><U+00B2><U+00AA> @ Sunny Bay Disney Land Resort https://t.co/a79L9ox6EU',
#  'No suit Sundays! @ Hong Kong https://t.co/xIryVrZ3EG',
#  'Last day n keep contact<ed><U+00A0><U+00BD><ed><U+00B2><U+0083><ed><U+00A0><U+00BC><ed><U+00BF><U+00BC><ed><U+00A0><U+00BD><ed><U+00B2><U+0083><ed><U+00A0><U+00BC><ed><U+00BF><U+00BC><ed><U+00A0><U+00BD><ed><U+00B2><U+0083><ed><U+00A0><U+00BC><ed><U+00BF><U+00BC> #<U+4E09><U+4F4D><U+7D30><U+98DF><U+7684><U+6E2F><U+5973> @ <U+9285><U+947C><U+7063><U+4E16><U+8CBF><U+4E2D><U+5FC3> <U+725B><U+6DAE><U+934B> https://t.co/mUNNN5hC6o',
#  'Almost two years ago this pic was taken and one of my old customer\x85 https://t.co/PQNKKLKVwB',
#  'Beautiful click by one wonderful customer. @ 8½ Otto e Mezzo Bombana https://t.co/q8gb4voJIv',
#  'A\x95O\x95P Pasta. Not even close to what I am used to. @ 8½ Otto e Mezzo\x85 https://t.co/yyinmbfYbr',
#  'Ice cream makes me happy. @bry5on_ missed you today ;) @ <U+5929><U+540E> Tin Hau https://t.co/Hbtrm00hn4',
#  'The big fat nose @ The Cabin - Cathay Pacific Lounge https://t.co/mPZ9JYKteY',
#  'Just posted a photo @ Ocean Park, Hongkong https://t.co/PcuRxuiidC',
#  'Still recovering from being Darth Vader at a 6-year olds star wars party @ Lions Nature Park,\x85 https://t.co/YbxJ7R2QnG',
#  'Had an inspiring and empowering weekend with some great people. \r\r\n\r\r\n#RTE #YSBH #motivation @\x85 https://t.co/h8k0t584pe',
#  '"Where is WOODY?"\r\r\n"There!" HAHAHAH @ Toy Story Land, Hong Kong Disneyland https://t.co/594CjUpDka',
#  'Fùnyìhng/ Huanyíng Hong Kong!\r\r\nSpectacular view from the skydrive on the #thepeak .\r\r\n#lightworks\x85 https://t.co/BQz04TJV3e',
#  "Happy Mother's Day!! <U+6BCD><U+89AA><U+7BC0><U+5FEB><U+6A02>!!\r\r\n<U+5ABD><U+5ABD><U+7B2C><U+4E00><U+6B21><U+770B><U+5230><U+6709><U+5716><U+6848><U+7684> Boomf <U+68C9><U+82B1><U+7CD6>,<U+89BA><U+5F97><U+597D><U+7279><U+5225>,<U+5FC3><U+60C5><U+5927><U+597D>~~<U+2764><U+2764>\r\r\n\r\r\nThank you Boomf for the\x85 https://t.co/gHShccCUsr",
#  "<U+6BCD><U+89AA><U+7BC0><U+5FEB><U+6A02>!Happy Mother's Day Dinner with my lovely family! I love you mom! <ed><U+00A0><U+00BD><ed><U+00B8><U+0098> @ <U+91D1><U+574A><U+6CF0><U+570B><U+7F8E><U+98DF><U+5206><U+5E97> https://t.co/DwpurkwTMy",
#  "Happy Mother's Day to you! I owe you this and yet am so far away from you! You are by far the\x85 https://t.co/x2gDIAJ5WY",
#  '#<U+6CF0><U+751F><U+8766> ~\r\r\n\r\r\n#<U+4EFB><U+98DF><U+4E00><U+756A> @ <U+6CF0><U+5F0F><U+540D><U+5EDA> https://t.co/oohjZN9Xwa',
#  'Home sweet home. (@ Wing Lok Street <U+6C38><U+6A02><U+8857> in Sheung Wan) https://t.co/X7Amu8ufLs',
#  'Home sweet home (@ Wing Lok Street <U+6C38><U+6A02><U+8857> in Sheung Wan) https://t.co/7v48YNlE5W',
#  '#<U+61F7><U+62B1><U+6CB9><U+6E23><U+9EB5> ~\r\r\n\r\r\n#<U+4EFB><U+98DF><U+4E00><U+756A> @ <U+82F1><U+8A18><U+6CB9><U+6E23><U+9EB5> https://t.co/Z3KPzp6koy',
#  '_<U+4F60><U+990A><U+6211><U+5C0F>,<U+6211><U+990A><U+4F60><U+8001><U+3002>\r\r\n<U+4E16><U+4E0A><U+6700><U+7F8E><U+597D><U+7684><U+4E8B><U+83AB><U+904E><U+65BC>:<U+6211><U+5DF2><U+7D93><U+9577><U+5927>,<U+4F60><U+9084><U+672A><U+8001><U+3002>\r\r\n<U+6211><U+6709><U+80FD><U+529B><U+5831><U+7B54>,<U+4F60><U+4ECD><U+7136><U+5065><U+5EB7>;\r\r\n<U+5C0D><U+4E0D><U+8D77><U+662F>,<U+5F9E><U+672A><U+8B93><U+4F60><U+9A55><U+50B2>,<U+4F60><U+537B><U+4F9D><U+7136><U+5F85><U+6211><U+5982><U+5BF6>  #<U+5ABD><U+54AA> <ed><U+00A0><U+00BD><ed><U+00B8><U+0098> #<U+6211><U+611B><U+4F60> <ed><U+00A0><U+00BD><ed><U+00B8><U+0098> #<U+6BCD><U+89AA><U+7BC0><U+5FEB><U+6A02>\r\r\n\r\r\n#hk\x85 https://t.co/Z5ClJ8EmDl',
#  "Enjoyin the night here in HK with the Young Hustlers!\r\r\nLet's go Hustle!\r\r\n#Mrworldwide\x85 https://t.co/h52G5tJGTY",
#  '<U+90FD><U+6709><U+5EFF><U+5E74><U+5187><U+5E6B><U+896F><U+904E><U+7FE0><U+83EF>,<U+771F><U+4FC2><U+6642><U+5149><U+5982><U+767D><U+99AC><U+904E><U+9699>\x85\x85<U+9EDE><U+904E><U+5440><U+5927><U+4F6C><U+3002> (@ Tsui Wah Restaurant <U+7FE0><U+83EF><U+9910><U+5EF3> in Mong Kok) https://t.co/fiwA7kFjm7',
#  '<U+4ECA><U+665A><U+6F14><U+5531><U+6703><U+7684><U+9020><U+578B>...\r\r\n#<U+5F90><U+4F73><U+7469><U+65E5><U+5168><U+8755><U+6F14><U+5531><U+6703><U+9999><U+6E2F><U+7AD9>\r\r\n#lala #<U+5F90><U+4F73><U+7469> #<U+65E5><U+5168><U+8755> #<U+6F14><U+5531><U+6703> #hk #hkig @ <U+4E5D><U+9F8D><U+7063><U+570B><U+969B><U+5C55><U+8CBF><U+4E2D><U+5FC3> Star Hall https://t.co/MX1Q6nN9YM',
#  '<U+4EE5><U+540E><U+51FA><U+95E8><U+4E00><U+5B9A><U+8981><U+5E26><U+5145><U+7535><U+5B9D><U+3002><U+3002><U+3002><U+3002> https://t.co/qUx0wtCIH7',
#  'Thanks again Hong Kong <ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0> for adding more great moments to this wicked adventure in life! <ed><U+00A0><U+00BC><ed><U+00BF><U+0092>\x85 https://t.co/TRE2EaWvgv',
#  '<U+51FA><U+4E86><U+5927><U+9646>,<U+4E00><U+5B9A><U+8981><U+7528><U+8C37><U+6B4C> https://t.co/yWwOUm56h6',
#  'Nice bump into you Sander Kleinberg in Hong Kong!!! #latepost #dutchdj #sanderkleinberg #random\x85 https://t.co/dw5332VSM1',
#  '<U+9999><U+6E2F><U+7684><U+868A><U+5B50><U+4E0D><U+662F><U+4E00><U+822C><U+7684><U+53B2><U+5BB3><U+3002><U+3002><U+3002><U+3002> https://t.co/csWiVy2beT',
#  '#AsiaWorks #leadershipprogram LP242 First Weekend completed!  These are the hard-working\x85 https://t.co/DjofhZZWyj',
#  "I'm at Hong Kong International Airport <U+9999><U+6E2F><U+570B><U+969B><U+6A5F><U+5834> (HKG) - @hkairport in Islands District, Hong Kong https://t.co/Uzhisl80CM",
#  'Goodbye Hong Kong thank you for everything we loved our time exploring your streets, eating your\x85 https://t.co/JCyHXivk4k',
#  "It's that time again! <U+2708><U+FE0F> #HongKong <ed><U+00A0><U+00BC><ed><U+00B7><U+00AD><ed><U+00A0><U+00BC><ed><U+00B7><U+00B0> #Taxi #BauerHockey Next stop #Indonesia <ed><U+00A0><U+00BC><ed><U+00B7><U+00AE><ed><U+00A0><U+00BC><ed><U+00B7><U+00A9> #Jakarta\x85 https://t.co/vT7Ig26Toy",
#  'Boats have never looked more beautiful\r\r\n\r\r\n#photography #photo #pic #picture #photographer\x85 https://t.co/cbPgtGDLqp',
#  '"There are 360 degrees, so why stick to one?" - Zaha Hadid @ <U+7406><U+5DE5><U+5927><U+5B78> Polytechnic University https://t.co/uNWee4sIzF',
#  'My first run since my ham string injury and look at what I get to see. Spectacular. @ The Hong\x85 https://t.co/TsfmDllUpy',
#  'My classmates...\r\r\nDWEP Group B\r\r\n#instagram #instamag #instalike\r\r\n#instamood #instacool #instadaily\x85 https://t.co/Tf0DPaA3ky',
#  'My classmates...\r\r\nDWEP Group B\r\r\n#instagram #instamag #instamood #instalike #instadaily #instacool\x85 https://t.co/dM6YpEKadD',
#  'I just finished running 5.40 km in 53m:56s with #Endomondo #endorphins https://t.co/RzCdlLt64j',
#  "It's not open till 7:30am. What is this? (@ Starbucks <U+661F><U+5DF4><U+514B> in Hung Hom, Hong Kong) https://t.co/L7vVg5rOE2",
#  "I'm at Kwun Tong Ferry Pier <U+89C0><U+5858><U+6E21><U+8F2A><U+78BC><U+982D> in Kwun Tong https://t.co/54t2rYIoJK",
#  'Just posted a photo @ 7eleven https://t.co/lnxrBOEZ8l',
#  'My classmates...\r\r\nFun with them selfie lover...\r\r\n#instagram #instamag #instalook #instalike\x85 https://t.co/cqnR3bYTLi',
#  'looking for models in HK please dm me #model #hongkong #hongkongmodel #hongkongmodeling\x85 https://t.co/M713ipQ3MS',
#  '#Vespa. Must be Italian @ Cheong Ming Street - Pacific Coffee https://t.co/WVOivCQGcF',
#  '#family #holiday #thepeak #hongkong @ Sky Terrace 428, The Peak, Hong Kong Site https://t.co/yZ5Z8xQO9e',
#  'Congee, Fried Noodles and Hot Milk Tea #breakfast @ cafe de coral-nathan Road Hongkong https://t.co/IGIUIqJBrJ',
#  'Letting go everything...<ed><U+00A0><U+00BD><ed><U+00B8><U+008A>\r\r\n#instagramers #instagram #instamag #instalike #instadaily #instamood\x85 https://t.co/6k7qXy6POP',
#  '#hongkong #skyline #sunset from the #port @ Port of Hong Kong https://t.co/Cx9k317BMU',
#  '<ed><U+00A0><U+00BD><ed><U+00B1><U+008A><ed><U+00A0><U+00BD><ed><U+00B1><U+008A>be yourself..\r\r\n#instagram\r\r\n#instagramers #instalook #instalike #instadaily #instamood #instacool\x85 https://t.co/mHw7lhA35V',
#  "I'm at @CitygateOutlets in Tung Chung https://t.co/xmjhod2zZn",
#  "I'm at MTR Tung Chung Station <U+6771><U+6D8C><U+7AD9> in Tung Chung https://t.co/8m1Xk5uw1P",
#  'Strictly bad ass at bikinifithk. #wod #shoulders #strictpress #maxreps #workout #bootcamp\x85 https://t.co/stIyyJQYaD',
#  'With #daddy forcing me to take picture hihi #Julianna #1yo #watchmegrow #hongkong @ Hong Kong https://t.co/rMiDnBOZW8',
#  'Not so crowded today, that should give us a breath',
#  ...]

# %%
number_of_tweet_user(final_dataframe)
# Out:
# Total number of tweet is: 241123; Total number of user is 12109

# %% [markdown]
# ## 8. The Summary of the Final Filtered Dataset
#
# In this part, we should work out the general information of these two pandas dataframe ```final_dataframe``` and ```total_dataframe```. We could consider the following aspects:
#
# 1. Language
# 2. Percentage of Geocoded Tweets
# 3. Number of tweets posted by users

# %%
number_of_tweet_user(final_dataframe)
# Out:
# Total number of tweet is: 241123; Total number of user is 12109

# %%
number_of_tweet_user(total_dataframe)
# Out:
# Total number of tweet is: 2883908; Total number of user is 179022

# %%
Counter(final_dataframe['lang'])
# Out:
# Counter({'en': 177497, 'zh': 63626})

# %%
fig, axes = plt.subplots(1,1,figsize=(10, 10), dpi=300)
x = ['English', 'Chinese']
y = [177497, 63626]
barlist = axes.bar(x, y, width=1/1.5)
barlist[0].set_color('#FFB828')
barlist[1].set_color('#3083FF')
fig.savefig(os.path.join(desktop, 'lang_distrib.png'))
plt.show()

# %%
filtered_tweet_num_geo_prop_list = compute_tweet_num_geo_prop(final_dataframe)
print(filtered_tweet_num_geo_prop_list[:5])
# Out:
# [(2, 0.5), (3, 0.3333333333333333), (2, 0.5), (23, 0.08695652173913043), (2, 0.5)]

# %%
filtered_tweet_num_list = [value[0] for value in filtered_tweet_num_geo_prop_list]
plot_cumulative(number_list=filtered_tweet_num_list, bin_num=40, color='green', title='Cumulative Distribution Tweet Number', 
                xlabel='Number of Posted Tweets', ylabel='Number of Users', saving_path=bot_check_figure_path, 
                file_name='Cumulative_dist_filtered_tweet_num.png')
